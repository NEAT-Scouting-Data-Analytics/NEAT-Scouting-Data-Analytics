# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
years = list(range(2011, 2024))
url_start = 'https://basketball.realgm.com/international/league/8/Greek-HEBA-A1/stats/{year}/Per_48/Qualified/All/points/{position}/desc/1/Regular_Season'
data = []  # List to store parsed data
for year in years:
    for position in ['PG', 'SG', 'SF', 'PF', 'C']:
        url = url_start.format(year=year, position=position)  # Correctly format the URL
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        for row in soup.select('.tablesaw tbody tr'):
            player = [year, position]  # Add the year and position to the player data
            player += [cell.text.strip() for cell in row.find_all('td')]
            data.append(player)
# Creating DataFrame from the collected data
columns = ['Year', 'Position', '#', 'Player', 'Team', 'GP', 'MPG', 'PPG', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
           'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'RPG', 'APG', 'SPG', 'BPG', 'TOV', 'PF']
df = pd.DataFrame(data, columns=columns)
# Save DataFrame to a CSV file
df.to_csv('greek_stats_with_positions.csv', index=False)
# Display DataFrame
df
# Out:
#       Year Position   #                  Player  Team  GP   MPG   PPG  FGM  \
# 0     2012       PG   1     Kosta Charalampidis  KAOD  22  28.2  26.6  7.9
# 1     2012       PG   2      Vassilis Spanoulis   OLY  31  23.2  24.1  7.9
# 2     2012       PG   3             David Logan   PAN  32  18.0  24.0  8.5
# 3     2012       PG   4    Sarunas Jasikevicius   PAN  35  16.6  23.8  8.8
# 4     2012       PG   5             Mike Taylor   KAV  22  28.1  23.7  8.2
# ...    ...      ...  ..                     ...   ...  ..   ...   ...  ...
# 1331  2023        C  18  Dimitrios Kaklamanakis  PAOK  18  14.2  11.5  5.1
# 1332  2023        C  19         Georgios Bogris   APO  22  22.5  11.0  4.9
# 1333  2023        C  20      Zisis Sarikopoulos  KARD  12   8.8  10.0  4.5
# 1334  2023        C  21      Michail Sprintzios   LAV  11   7.4   6.5  2.4
# 1335  2023        C  22       Georgios Kogionis   APO  17   4.8   0.0  0.0
#
#        FGA   FG%  3PM  3PA   3P%  FTM  FTA   FT%  ORB  DRB   RPG   APG  SPG  \
# 0     16.9  .468  2.2  6.0  .377  8.6  9.5  .902  0.6  4.4   5.0   7.4  1.3
# 1     18.4  .431  2.6  7.7  .336  6.2  7.6  .816  0.7  3.7   4.4  10.3  1.7
# 2     18.7  .453  2.7  7.1  .384  4.3  5.2  .825  0.7  2.7   3.3   3.5  3.6
# 3     16.9  .522  2.5  5.4  .462  3.6  4.5  .815  0.5  1.9   2.4   9.1  0.7
# 4     19.2  .429  2.5  7.4  .337  4.8  6.3  .765  1.4  5.0   6.4   3.4  2.2
# ...    ...   ...  ...  ...   ...  ...  ...   ...  ...  ...   ...   ...  ...
# 1331  10.3  .491  0.0  0.0  .000  1.3  2.6  .500  5.5  8.3  13.7   3.6  1.3
# 1332   9.1  .543  0.0  0.0  .000  1.1  1.6  .647  3.0  7.8  10.8   3.9  1.2
# 1333  10.4  .435  0.0  0.0  .000  0.9  1.8  .500  5.9  8.2  14.0   1.4  0.9
# 1334   7.7  .308  1.8  5.9  .300  0.0  1.2  .000  0.6  4.2   4.7   1.8  1.8
# 1335   4.1  .000  0.0  0.6  .000  0.0  0.0  .000  2.3  7.6   9.9   1.2  1.2
#
#       BPG  TOV   PF
# 0     0.1  5.0  3.3
# 1     0.0  4.7  3.2
# 2     0.2  2.6  4.7
# 3     0.2  3.7  5.4
# 4     0.5  5.5  5.4
# ...   ...  ...  ...
# 1331  1.1  3.8  5.5
# 1332  0.4  2.5  6.4
# 1333  0.9  2.3  5.9
# 1334  0.0  1.2  8.3
# 1335  0.0  0.6  1.7
#
# [1336 rows x 25 columns]

# %%
greek_stats_with_positions = df

# %%
greek_stats_with_positions['Position'] = greek_stats_with_positions['Position'].replace(['PG', 'SG'], 'G')
greek_stats_with_positions['Position'] = greek_stats_with_positions['Position'].replace(['SF', 'PF'], 'F')

# %%
# Scrape Player Bio in German BBL

import requests
from bs4 import BeautifulSoup
import pandas as pd

pd.set_option('display.max_columns', None)  # so we can see all columns in a wide DataFrame

years = list(range(2019, 2025))

url_start = "https://basketball.realgm.com/international/league/8/Greek-HEBA-A1/players/{}/{}"

data = []  # List to store parsed data
index = ['663', '767', '868', '957', '1051']
for index, year in zip(index, years):
    url = url_start.format(index, year)  # Properly formatted URL
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    rows = soup.select('.tablesaw tbody tr')
    print(f"Year: {year}, Rows: {len(rows)}")  # Debugging print

    for row in rows:
        player = [year]  # Add the year and position to the player data
        player += [cell.text.strip() for cell in row.find_all('td')]
        data.append(player)

# Extracting column names from the first row of the table
columns = ['Year'] + [header.text.strip() for header in soup.select('.tablesaw thead th')]

# Creating DataFrame from the collected data
df = pd.DataFrame(data, columns=columns)

# Displaying just the first few rows for clarity
df
# Out:
# Year: 2019, Rows: 260
# Year: 2020, Rows: 282
# Year: 2021, Rows: 241
# Year: 2022, Rows: 257
# Year: 2023, Rows: 227
#       Year                 Player Pos    HT   WT                   Team  \
# 0     2019         Danny Agbelese   F   6-8  215               Holargos
# 1     2019         Alex Aggelakos  SF   6-6    -      Kolossos Rodou BC
# 2     2019    Dimitrios Agravanis   F  6-10  210             Olympiacos
# 3     2019      Ioannis Agravanis  SF   6-6  198           Peristeri BC
# 4     2019       Georgios Angelou  PG   6-1  185                Aris BC
# ...    ...                    ...  ..   ...  ...                    ...
# 1262  2023  Vassilis Xanthopoulos  PG   6-2  205             AEK Athens
# 1263  2023            James Young  SG   6-6  215      Kolossos Rodou BC
# 1264  2023              Joe Young   G   6-2  180  ASP Promitheas Patras
# 1265  2023         Thodoris Zaras  SG   6-5  215              GS Lavrio
# 1266  2023      Evangelos Zougris   F   6-8  249           Peristeri BC
#
#           Birth City               Draft Status    Nationality
# 0        Lanham (MD)  2012 NBA Draft, Undrafted  United States
# 1             Rhodes  2016 NBA Draft, Undrafted         Greece
# 2             Athens         2015 Rnd 2 Pick 29         Greece
# 3          Amarousio  2020 NBA Draft, Undrafted         Greece
# 4             Athens  2017 NBA Draft, Undrafted         Greece
# ...              ...                        ...            ...
# 1262    Thessaloniki  2006 NBA Draft, Undrafted         Greece
# 1263  Rochester (MI)         2014 Rnd 1 Pick 17  United States
# 1264    Houston (TX)         2015 Rnd 2 Pick 13  United States
# 1265    Thessaloniki  2009 NBA Draft, Undrafted         Greece
# 1266             N/A    2026 NBA Draft Eligible         Greece
#
# [1267 rows x 9 columns]

# %%
greek_bio_players = df

# %%
# Assuming british_merged_df is your DataFrame
greek_bio_players.to_csv('greek_bio_players.csv', index=False)

# %%
greek_bio_players['Pos'] = greek_bio_players['Pos'].replace(['PG', 'SG'], 'G')
greek_bio_players['Pos'] = greek_bio_players['Pos'].replace(['SF', 'PF'], 'F')

# %%
import pandas as pd

# Load the datasets
greek_stats_with_positions = pd.read_csv('/Users/allendcosta/NBA-NEAT/NEAT-Scouting-Data-Analytics/DataFiles/Greek/greek_stats_with_positions.csv')
greek_bio_players = pd.read_csv('/Users/allendcosta/NBA-NEAT/NEAT-Scouting-Data-Analytics/DataFiles/Greek/greek_bio_players.csv')

# Merge the datasets on the "Player" column
merged_df = pd.merge(greek_bio_players, greek_stats_with_positions, on='Player', how='inner')

# Save the merged DataFrame to a CSV file
merged_df.to_csv('merged_greek_bio_stats_data.csv', index=False)

# Display the merged DataFrame
merged_df
merged_greek_df = merged_df

# %%
merged_greek_df
# Out:
#       Year_x            Player Pos    HT   WT                 Team_x  \
# 0       2019    Danny Agbelese   F   6-8  215               Holargos
# 1       2019    Danny Agbelese   F   6-8  215               Holargos
# 2       2019    Danny Agbelese   F   6-8  215               Holargos
# 3       2019    Danny Agbelese   F   6-8  215               Holargos
# 4       2020    Danny Agbelese   F   6-8  215      Kolossos Rodou BC
# ...      ...               ...  ..   ...  ...                    ...
# 2692    2023       Jarrod West   G  5-11  180           AS Karditsas
# 2693    2023  Derrick Williams   F   6-8  240          Panathinaikos
# 2694    2023      Nate Wolters   G   6-4  190          Panathinaikos
# 2695    2023       James Young   G   6-6  215      Kolossos Rodou BC
# 2696    2023         Joe Young   G   6-2  180  ASP Promitheas Patras
#
#            Birth City               Draft Status    Nationality  Year_y  \
# 0         Lanham (MD)  2012 NBA Draft, Undrafted  United States    2019
# 1         Lanham (MD)  2012 NBA Draft, Undrafted  United States    2020
# 2         Lanham (MD)  2012 NBA Draft, Undrafted  United States    2021
# 3         Lanham (MD)  2012 NBA Draft, Undrafted  United States    2022
# 4         Lanham (MD)  2012 NBA Draft, Undrafted  United States    2019
# ...               ...                        ...            ...     ...
# 2692  Clarksburg (WV)  2023 NBA Draft, Undrafted  United States    2023
# 2693  Bellflower (CA)          2011 Rnd 1 Pick 2  United States    2023
# 2694   St. Cloud (MN)          2013 Rnd 2 Pick 8  United States    2023
# 2695   Rochester (MI)         2014 Rnd 1 Pick 17  United States    2023
# 2696     Houston (TX)         2015 Rnd 2 Pick 13  United States    2023
#
#      Position   # Team_y  GP   MPG   PPG   FGM   FGA    FG%  3PM   3PA    3P%  \
# 0          SF  10    HOL  29  23.6  16.9   7.1  12.5  0.564  0.0   0.1  0.000
# 1           C  12    KOL  20  21.9  21.5   8.0  13.3  0.603  0.0   0.0  0.000
# 2          PF   8   PROM  34  17.8  21.4   9.0  14.3  0.630  0.1   0.2  0.333
# 3          PF  29    PER  11  14.8  14.8   6.5  11.5  0.564  0.0   0.0  0.000
# 4          SF  10    HOL  29  23.6  16.9   7.1  12.5  0.564  0.0   0.1  0.000
# ...       ...  ..    ...  ..   ...   ...   ...   ...    ...  ...   ...    ...
# 2692       PG  30   KARD  12  21.5   8.2   2.8  11.7  0.238  1.7   8.0  0.209
# 2693       PF  18    PAN  31  17.0  16.2   5.8  13.5  0.432  2.6   7.2  0.367
# 2694       PG  16    PAN  14  16.8  17.4   7.4  15.9  0.462  1.0   4.7  0.217
# 2695       SG   5    KOL  10  16.3  26.7   8.8  18.5  0.476  5.3  12.6  0.419
# 2696       SG   2   PROM   6  23.5  32.7  11.6  24.5  0.472  3.4   9.2  0.370
#
#       FTM  FTA    FT%  ORB   DRB   RPG  APG  SPG  BPG  TOV   PF
# 0     2.8  4.3  0.656  4.1  10.1  14.1  1.7  1.1  3.6  3.2  6.8
# 1     5.5  8.3  0.658  3.8   7.0  10.9  2.0  1.1  2.9  3.4  7.9
# 2     3.2  5.9  0.554  4.2   8.3  12.5  2.5  1.1  3.9  4.7  7.1
# 3     1.8  3.5  0.500  5.6   6.2  11.8  2.7  1.2  2.7  3.0  8.6
# 4     2.8  4.3  0.656  4.1  10.1  14.1  1.7  1.1  3.6  3.2  6.8
# ...   ...  ...    ...  ...   ...   ...  ...  ...  ...  ...  ...
# 2692  0.9  1.3  0.714  0.9   3.5   4.5  6.0  2.6  0.0  2.8  5.6
# 2693  1.9  2.9  0.656  1.0   4.5   5.5  2.5  1.5  0.2  2.1  2.5
# 2694  1.6  3.1  0.533  0.6   8.2   8.8  7.6  3.1  0.0  3.9  3.5
# 2695  3.8  6.5  0.591  2.1   7.6   9.7  2.6  2.1  0.6  0.9  5.6
# 2696  6.1  6.5  0.947  1.0   3.4   4.4  4.4  0.7  0.0  2.0  3.7
#
# [2697 rows x 33 columns]

# %%
# Assuming british_merged_df is your DataFrame
merged_greek_df['League'] = 'Greek Basketball League'

# Display DataFrame
merged_greek_df
# Out:
#       Year_x            Player Pos    HT   WT                 Team_x  \
# 0       2019    Danny Agbelese   F   6-8  215               Holargos
# 1       2019    Danny Agbelese   F   6-8  215               Holargos
# 2       2019    Danny Agbelese   F   6-8  215               Holargos
# 3       2019    Danny Agbelese   F   6-8  215               Holargos
# 4       2020    Danny Agbelese   F   6-8  215      Kolossos Rodou BC
# ...      ...               ...  ..   ...  ...                    ...
# 2692    2023       Jarrod West   G  5-11  180           AS Karditsas
# 2693    2023  Derrick Williams   F   6-8  240          Panathinaikos
# 2694    2023      Nate Wolters   G   6-4  190          Panathinaikos
# 2695    2023       James Young   G   6-6  215      Kolossos Rodou BC
# 2696    2023         Joe Young   G   6-2  180  ASP Promitheas Patras
#
#            Birth City               Draft Status    Nationality  Year_y  \
# 0         Lanham (MD)  2012 NBA Draft, Undrafted  United States    2019
# 1         Lanham (MD)  2012 NBA Draft, Undrafted  United States    2020
# 2         Lanham (MD)  2012 NBA Draft, Undrafted  United States    2021
# 3         Lanham (MD)  2012 NBA Draft, Undrafted  United States    2022
# 4         Lanham (MD)  2012 NBA Draft, Undrafted  United States    2019
# ...               ...                        ...            ...     ...
# 2692  Clarksburg (WV)  2023 NBA Draft, Undrafted  United States    2023
# 2693  Bellflower (CA)          2011 Rnd 1 Pick 2  United States    2023
# 2694   St. Cloud (MN)          2013 Rnd 2 Pick 8  United States    2023
# 2695   Rochester (MI)         2014 Rnd 1 Pick 17  United States    2023
# 2696     Houston (TX)         2015 Rnd 2 Pick 13  United States    2023
#
#      Position   # Team_y  GP   MPG   PPG   FGM   FGA    FG%  3PM   3PA    3P%  \
# 0          SF  10    HOL  29  23.6  16.9   7.1  12.5  0.564  0.0   0.1  0.000
# 1           C  12    KOL  20  21.9  21.5   8.0  13.3  0.603  0.0   0.0  0.000
# 2          PF   8   PROM  34  17.8  21.4   9.0  14.3  0.630  0.1   0.2  0.333
# 3          PF  29    PER  11  14.8  14.8   6.5  11.5  0.564  0.0   0.0  0.000
# 4          SF  10    HOL  29  23.6  16.9   7.1  12.5  0.564  0.0   0.1  0.000
# ...       ...  ..    ...  ..   ...   ...   ...   ...    ...  ...   ...    ...
# 2692       PG  30   KARD  12  21.5   8.2   2.8  11.7  0.238  1.7   8.0  0.209
# 2693       PF  18    PAN  31  17.0  16.2   5.8  13.5  0.432  2.6   7.2  0.367
# 2694       PG  16    PAN  14  16.8  17.4   7.4  15.9  0.462  1.0   4.7  0.217
# 2695       SG   5    KOL  10  16.3  26.7   8.8  18.5  0.476  5.3  12.6  0.419
# 2696       SG   2   PROM   6  23.5  32.7  11.6  24.5  0.472  3.4   9.2  0.370
#
#       FTM  FTA    FT%  ORB   DRB   RPG  APG  SPG  BPG  TOV   PF  \
# 0     2.8  4.3  0.656  4.1  10.1  14.1  1.7  1.1  3.6  3.2  6.8
# 1     5.5  8.3  0.658  3.8   7.0  10.9  2.0  1.1  2.9  3.4  7.9
# 2     3.2  5.9  0.554  4.2   8.3  12.5  2.5  1.1  3.9  4.7  7.1
# 3     1.8  3.5  0.500  5.6   6.2  11.8  2.7  1.2  2.7  3.0  8.6
# 4     2.8  4.3  0.656  4.1  10.1  14.1  1.7  1.1  3.6  3.2  6.8
# ...   ...  ...    ...  ...   ...   ...  ...  ...  ...  ...  ...
# 2692  0.9  1.3  0.714  0.9   3.5   4.5  6.0  2.6  0.0  2.8  5.6
# 2693  1.9  2.9  0.656  1.0   4.5   5.5  2.5  1.5  0.2  2.1  2.5
# 2694  1.6  3.1  0.533  0.6   8.2   8.8  7.6  3.1  0.0  3.9  3.5
# 2695  3.8  6.5  0.591  2.1   7.6   9.7  2.6  2.1  0.6  0.9  5.6
# 2696  6.1  6.5  0.947  1.0   3.4   4.4  4.4  0.7  0.0  2.0  3.7
#
#                        League
# 0     Greek Basketball League
# 1     Greek Basketball League
# 2     Greek Basketball League
# 3     Greek Basketball League
# 4     Greek Basketball League
# ...                       ...
# 2692  Greek Basketball League
# 2693  Greek Basketball League
# 2694  Greek Basketball League
# 2695  Greek Basketball League
# 2696  Greek Basketball League
#
# [2697 rows x 34 columns]
