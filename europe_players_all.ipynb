# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # so we can see all columns in a wide DataFrame

# %%
df_stats = pd.read_csv('/Users/pandit1781/NEAT-Scouting-Data-Analytics/sql_export/european_players_final.csv', low_memory=False)

# %%
df_stats.head()
# Out:
#    Year Position           Player Team    GP    MPG    PPG   FGM    FGA   FG%  \
# 0  2019        G  Nikola Ivanovic  BUD   8.0  22.25  23.62  5.12  15.25  0.42
# 1  2020        G  Nikola Ivanovic  BUD  18.0  28.62  25.50  8.25  18.62  0.56
# 2  2021        G  Nikola Ivanovic  BUD  31.0  32.75  29.50  8.62  19.88  0.54
# 3  2020        G       Luka Bozic  BUD  15.0  14.12  18.50  7.12  14.62  0.61
# 4  2019        G   Nemanja Gordic  BUD  30.0  30.38  23.25  7.62  18.38  0.52
#
#     3PM   3PA   3P%    FTM    FTA   FT%   ORB   DRB   RPG    APG   SPG  BPG  \
# 0  3.00  7.62  0.49  10.50  11.88  1.12  1.25  2.12  3.38   8.88  3.38  0.0
# 1  3.62  9.62  0.47   5.25   6.50  1.00  0.62  5.50  6.12  11.00  3.38  0.0
# 2  3.12  9.88  0.39   9.25  10.88  1.06  1.25  5.12  6.38  11.25  3.25  0.0
# 3  2.12  5.38  0.50   2.12   3.50  0.75  2.12  6.00  8.12   3.88  2.88  0.0
# 4  2.00  7.38  0.33   5.88   8.62  0.86  0.38  4.25  4.62  10.75  1.38  0.0
#
#     TOV    PF  3PM/FGM  APG_TOV  FG3A%    HT        League  \
# 0  2.50  3.75     0.59     3.55   0.50  1.91  Adriatic ABA
# 1  3.00  5.88     0.44     3.67   0.52  1.91  Adriatic ABA
# 2  3.88  4.12     0.36     2.90   0.50  1.91  Adriatic ABA
# 3  3.50  5.62     0.30     1.11   0.37  1.96  Adriatic ABA
# 4  4.12  5.38     0.26     2.61   0.40  1.93  Adriatic ABA
#
#               Nationality League Country
# 0              Montenegro     Montenegro
# 1              Montenegro     Montenegro
# 2              Montenegro     Montenegro
# 3                 Croatia     Montenegro
# 4  Bosnia and Herzegovina     Montenegro

# %%
df_stats.query('`League Country` == "Lithuania" and RPG > 13 and BPG > 2 and APG > 3').nunique()
# Out:
# Year               6
# Position           3
# Player            34
# Team              12
# GP                28
# MPG               45
# PPG               39
# FGM               39
# FGA               41
# FG%               32
# 3PM               17
# 3PA               22
# 3P%               24
# FTM               40
# FTA               35
# FT%               35
# ORB               34
# DRB               36
# RPG               34
# APG               19
# SPG               20
# BPG               18
# TOV               28
# PF                36
# 3PM/FGM           18
# APG_TOV           42
# FG3A%             20
# HT                 9
# League             1
# Nationality       10
# League Country     1
# dtype: int64

# %%
filtered_df = df_stats[(df_stats['Position'] == 'C') & (df_stats['League Country'] == 'France') & (df_stats['APG'] >= 3.0) & 
                                     (df_stats['BPG'] >= 2.0) & (df_stats['RPG'] >= 13.0) & (df_stats['HT'] >= 2.13)]
filtered_df.nunique()
# Out:
# Year              2
# Position          1
# Player            3
# Team              4
# GP                4
# MPG               4
# PPG               4
# FGM               4
# FGA               4
# FG%               4
# 3PM               3
# 3PA               3
# 3P%               3
# FTM               4
# FTA               4
# FT%               3
# ORB               4
# DRB               4
# RPG               4
# APG               4
# SPG               4
# BPG               4
# TOV               4
# PF                4
# 3PM/FGM           3
# APG_TOV           4
# FG3A%             4
# HT                3
# League            1
# Nationality       2
# League Country    1
# dtype: int64

# %%
filtered_df = df_stats[(df_stats['Position'] == 'C')]
filtered_df.max()
# Out:
# Year                           2024
# Position                          C
# Player            Zygimantas Skucas
# Team                            ZVE
# GP                             46.0
# MPG                           50.31
# PPG                           57.34
# FGM                           23.91
# FGA                           35.47
# FG%                            1.25
# 3PM                            7.34
# 3PA                           15.78
# 3P%                            1.56
# FTM                            17.0
# FTA                           23.75
# FT%                            1.56
# ORB                           16.72
# DRB                           19.25
# RPG                            31.5
# APG                            15.0
# SPG                             6.0
# BPG                            7.75
# TOV                           15.47
# PF                            21.09
# 3PM/FGM                        0.78
# APG_TOV                         inf
# FG3A%                          0.77
# HT                             2.24
# League                  Turkish BSL
# Nationality                Zimbabwe
# League Country       United Kingdom
# dtype: object
