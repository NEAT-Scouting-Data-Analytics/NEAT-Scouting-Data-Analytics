# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
#Import dataframes 

df_stats_Croatia = pd.read_csv('DataFiles/euroleague_stats_Croatia.csv')
df_player_stats_Croatia= pd.read_csv('DataFiles/euroleague_stats_Croatia_player.csv')

# %%
df_player_stats_Croatia.nunique()
# Out:
# Year              5
# Player          591
# Pos               6
# HT               21
# WT               77
# Team             18
# Birth City      160
# Draft Status     36
# Nationality      46
# dtype: int64

# %%
df_player_stats_Croatia=df_player_stats_Croatia.drop_duplicates(subset=['Player'])

# %%
df_player_stats_Croatia
# Out:
#       Year           Player Pos   HT   WT                 Team     Birth City  \
# 0     2019     Bashir Ahmed   F  6-7  210             KK Zadar  New York (NY)
# 1     2019      Byron Allen   C  6-7  275             KK Zadar    Leland (MS)
# 2     2019  Andro Anzulovic   G  6-4  200             KK Zabok         Zagreb
# 3     2019   Roko Anzulovic   G  6-5    -  KK Hermes Znalitica            NaN
# 4     2019      Marko Atelj  GF  6-5  205   KK Sonik Puntamika          Zadar
# ...    ...              ...  ..  ...  ...                  ...            ...
# 1088  2023      Marko Vucic   F  6-7    -            KK Cibona            NaN
# 1089  2023    Petar Vujacic   G  6-4  198             KK Zadar        Maribor
# 1091  2023    Jakov Vujicic   G  6-2    -         KK Dubrovnik            NaN
# 1094  2023   Kahlil Whitney   F  6-6  210          KK Skrljevo   Chicago (IL)
# 1096  2023     Matija Zoric   C  6-9    -         KK Dubrovnik            NaN
#
#                    Draft Status    Nationality
# 0     2018 NBA Draft, Undrafted  United States
# 1     2006 NBA Draft, Undrafted  United States
# 2     2013 NBA Draft, Undrafted        Croatia
# 3     2018 NBA Draft, Undrafted        Croatia
# 4     2013 NBA Draft, Undrafted        Croatia
# ...                         ...            ...
# 1088    2026 NBA Draft Eligible        Croatia
# 1089  2022 NBA Draft, Undrafted       Slovenia
# 1091    2025 NBA Draft Eligible        Croatia
# 1094  2020 NBA Draft, Undrafted  United States
# 1096    2027 NBA Draft Eligible        Croatia
#
# [591 rows x 9 columns]

# %%
# columns_to_delete = ['PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2', 'TD3', 'WNBA_FANTASY_PTS', 'GP_RANK',
#                      'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK',
#                      'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK',
#                      'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK',
#                      'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK',
#                      'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK',
#                      'DD2_RANK', 'TD3_RANK', 'WNBA_FANTASY_PTS_RANK']

# # Delete the specified columns
# df_player_stats.drop(columns=columns_to_delete, inplace=True, errors='ignore')

# df_player_stats.rename(columns={'Season_type': 'Season'}, inplace=True)

# %%
# Merge 'df_player_stats' and ‘df_bio‘ on common keys ‘PLAYER_ID‘ and ‘Year‘ in order to get 'COUNTRY' column.
merged_df_stats_Croatia = pd.merge(df_stats_Croatia, df_player_stats_Croatia, on=['Player'], how='inner')

#columns_to_delete_merged = ['GP_y','PTS_y','REB_y','AST_y','NET_RATING','OREB_PCT','DREB_PCT','USG_PCT', 'TS_PCT','AST_PCT']

#merged_df_stats_bio.drop(columns=columns_to_delete_merged, inplace=True)

# %%
# Checking the result of 'merged_df_stats_bio'
merged_df_stats_Croatia
# Out:
#      Year_x Position   #             Player Team_x    GP     MPG     PPG  \
# 0      2019        G   1   Martin Junakovic    SIB  11.0  39.875  37.125
# 1      2020        G   4   Martin Junakovic    ZAD  16.0  28.750  30.750
# 2      2021        G  10   Martin Junakovic    ZAD  38.0  23.750  25.500
# 3      2022        G   9   Martin Junakovic    ZAD  38.0  28.875  25.750
# 4      2019        G   2  Kresimir Radovcic    ZAB  23.0  34.250  34.375
# ..      ...      ...  ..                ...    ...   ...     ...     ...
# 651    2023        C  19     Emeka Obukwelu   SRKL  12.0  24.875  19.625
# 652    2023        C  20         Ivan Juric    DUB  16.0   7.500  19.500
# 653    2023        C  21       Mario Kresic    RIB   2.0  25.750  17.500
# 654    2023        C  24   Jakov Stipanicev    ZAB  33.0  20.250  14.500
# 655    2023        C  26      Petar Markota    RIB   2.0  22.125  13.500
#
#         FGM     FGA      FG%    3PM    3PA      3P%    FTM     FTA      FT%  \
# 0    12.875  29.875  0.53625  2.375  9.000  0.33000  9.000  10.750  1.05125
# 1    10.375  22.500  0.58000  2.875  9.000  0.40875  7.000   9.500  0.92625
# 2     8.500  20.375  0.52375  2.375  7.750  0.38625  6.000   8.000  0.93750
# 3     9.000  20.750  0.54000  1.750  5.000  0.42250  6.125   8.625  0.89250
# 4    12.250  27.375  0.56000  3.250  9.375  0.42875  6.500   7.750  1.06500
# ..      ...     ...      ...    ...    ...      ...    ...     ...      ...
# 651   7.000  16.125  0.54750  1.500  5.000  0.37500  4.000   5.250  0.95250
# 652   7.500  18.250  0.51750  0.625  1.875  0.41625  3.750   6.875  0.68125
# 653   5.875  17.500  0.41625  2.875  5.875  0.62500  2.875   2.875  1.25000
# 654   4.500  13.625  0.41375  1.625  7.125  0.29250  3.875   5.125  0.92375
# 655   6.750  16.875  0.50000  0.000  0.000  0.00000  0.000   3.375  0.00000
#
#        ORB     DRB     RPG     APG    SPG    BPG    TOV      PF  Year_y Pos  \
# 0    0.875   5.625   6.500  11.750  4.250  0.125  6.875   4.750    2019   G
# 1    1.000   4.750   5.750  11.500  4.375  0.125  6.875   7.375    2019   G
# 2    1.375   3.375   4.625   9.500  2.875  0.125  5.125   7.875    2019   G
# 3    1.375   3.500   4.875  11.750  2.375  0.125  5.000   7.375    2019   G
# 4    1.375   5.750   7.000   8.250  2.625  0.000  5.000   5.000    2020   G
# ..     ...     ...     ...     ...    ...    ...    ...     ...     ...  ..
# 651  2.000  10.500  12.625   2.000  0.000  0.500  3.000   7.250    2022   F
# 652  6.875   8.750  15.750   1.875  1.875  0.625  8.125   9.375    2022   C
# 653  1.500   7.250   8.750   1.500  1.500  2.875  2.875  13.125    2022   C
# 654  3.500   8.625  12.125   2.375  1.625  2.375  3.375   9.375    2022   C
# 655  5.125  13.500  18.625   0.000  0.000  5.125  3.375   8.500    2022   C
#
#        HT   WT             Team_y  Birth City               Draft Status  \
# 0     6-2  195           KK Zadar     Sibenik  2016 NBA Draft, Undrafted
# 1     6-2  195           KK Zadar     Sibenik  2016 NBA Draft, Undrafted
# 2     6-2  195           KK Zadar     Sibenik  2016 NBA Draft, Undrafted
# 3     6-2  195           KK Zadar     Sibenik  2016 NBA Draft, Undrafted
# 4     6-5  194          KK Cibona     Sibenik  2019 NBA Draft, Undrafted
# ..    ...  ...                ...         ...                        ...
# 651   6-8  235        KK Skrljevo  Plano (TX)  2022 NBA Draft, Undrafted
# 652  6-11  229  KK Dubrava Zagreb         NaN    2028 NBA Draft Eligible
# 653   6-7    -  KK Ribola Kastela         NaN    2024 NBA Draft Eligible
# 654  6-11    -           KK Zabok  Novo Mesto  2021 NBA Draft, Undrafted
# 655   6-7    -  KK Ribola Kastela         NaN    2025 NBA Draft Eligible
#
#        Nationality
# 0          Croatia
# 1          Croatia
# 2          Croatia
# 3          Croatia
# 4          Croatia
# ..             ...
# 651  United States
# 652        Croatia
# 653        Croatia
# 654       Slovenia
# 655        Croatia
#
# [656 rows x 33 columns]

# %%
merged_df_stats_Turkey[merged_df_stats_Turkey['Player'] == 'Shane Larkin']
# Out:
#    Year_x Position   #        Player Team_x    GP     MPG     PPG    FGM  \
# 2    2019        G   3  Shane Larkin    EFE  24.0  34.625  18.875  6.125
# 3    2020        G  10  Shane Larkin    EFE  10.0  29.625  16.125  5.375
# 4    2021        G  22  Shane Larkin    EFE  23.0  23.625  10.250  3.125
# 5    2022        G  14  Shane Larkin    EFE  31.0  31.375  14.750  4.375
# 6    2023        G  18  Shane Larkin    EFE  28.0  34.000  14.125  4.375
#
#       FGA      FG%    3PM    3PA      3P%   FTM    FTA      FT%    ORB    DRB  \
# 2  13.250  0.57375  2.500  6.625  0.45875  4.25  4.500  1.17875  0.875  2.500
# 3  12.500  0.53750  2.375  7.750  0.38250  3.00  3.125  1.20000  1.125  2.250
# 4   7.375  0.52375  2.250  5.625  0.51000  1.75  2.125  1.05750  0.125  2.125
# 5  10.375  0.53250  3.000  7.500  0.50375  3.00  3.250  1.12750  0.375  3.125
# 6   9.875  0.56250  2.500  7.000  0.45625  2.75  3.250  1.05875  0.375  3.000
#
#      RPG    APG    SPG    BPG    TOV     PF  Year_y Pos    HT   WT  \
# 2  3.500  5.625  1.875  0.125  2.500  2.375    2019   G  5-11  175
# 3  3.375  5.000  1.750  0.125  2.125  1.750    2019   G  5-11  175
# 4  2.375  4.000  0.750  0.000  1.500  1.000    2019   G  5-11  175
# 5  3.500  6.250  1.000  0.125  2.875  1.500    2019   G  5-11  175
# 6  3.375  5.625  1.500  0.125  2.250  1.875    2019   G  5-11  175
#
#          Team_y       Birth City        Draft Status          Nationality
# 2  Anadolu Efes  Cincinnati (OH)  2013 Rnd 1 Pick 18  United StatesTurkey
# 3  Anadolu Efes  Cincinnati (OH)  2013 Rnd 1 Pick 18  United StatesTurkey
# 4  Anadolu Efes  Cincinnati (OH)  2013 Rnd 1 Pick 18  United StatesTurkey
# 5  Anadolu Efes  Cincinnati (OH)  2013 Rnd 1 Pick 18  United StatesTurkey
# 6  Anadolu Efes  Cincinnati (OH)  2013 Rnd 1 Pick 18  United StatesTurkey

# %%
merged_df_stats_Turkey[merged_df_stats_Turkey.groupby('Player').transform('size')>4]
# Out:
#      Year_x Position   #        Player Team_x    GP     MPG     PPG    FGM  \
# 2      2019        G   3  Shane Larkin    EFE  24.0  34.625  18.875  6.125
# 3      2020        G  10  Shane Larkin    EFE  10.0  29.625  16.125  5.375
# 4      2021        G  22  Shane Larkin    EFE  23.0  23.625  10.250  3.125
# 5      2022        G  14  Shane Larkin    EFE  31.0  31.375  14.750  4.375
# 6      2023        G  18  Shane Larkin    EFE  28.0  34.000  14.125  4.375
# ..      ...      ...  ..           ...    ...   ...     ...     ...    ...
# 527    2021        C  13  Egemen Guven   AFYO  28.0  28.625  13.625  5.875
# 528    2022        C  15  Egemen Guven   BURS  15.0  22.750   9.625  4.250
# 529    2022        C  21  Egemen Guven    EFE  22.0  13.000   6.500  3.000
# 530    2023        C  21  Egemen Guven    BES  18.0  19.625   8.250  3.500
# 531    2023        C  27  Egemen Guven    EFE  11.0   8.875   4.250  1.750
#
#         FGA      FG%    3PM    3PA      3P%    FTM    FTA      FT%    ORB  \
# 2    13.250  0.57375  2.500  6.625  0.45875  4.250  4.500  1.17875  0.875
# 3    12.500  0.53750  2.375  7.750  0.38250  3.000  3.125  1.20000  1.125
# 4     7.375  0.52375  2.250  5.625  0.51000  1.750  2.125  1.05750  0.125
# 5    10.375  0.53250  3.000  7.500  0.50375  3.000  3.250  1.12750  0.375
# 6     9.875  0.56250  2.500  7.000  0.45625  2.750  3.250  1.05875  0.375
# ..      ...      ...    ...    ...      ...    ...    ...      ...    ...
# 527  10.875  0.67375  0.375  1.000  0.38000  1.625  2.250  0.88250  2.500
# 528   7.500  0.70875  0.000  0.125  0.00000  1.125  1.875  0.79500  1.625
# 529   4.625  0.79250  0.125  0.500  0.31250  0.500  0.750  0.76875  1.375
# 530   6.000  0.72625  0.625  1.000  0.75000  0.750  1.125  0.78125  1.625
# 531   2.750  0.78125  0.125  0.250  0.62500  0.625  0.750  1.07125  0.500
#
#        DRB    RPG    APG    SPG    BPG    TOV     PF  Year_y Pos    HT   WT  \
# 2    2.500  3.500  5.625  1.875  0.125  2.500  2.375    2019   G  5-11  175
# 3    2.250  3.375  5.000  1.750  0.125  2.125  1.750    2019   G  5-11  175
# 4    2.125  2.375  4.000  0.750  0.000  1.500  1.000    2019   G  5-11  175
# 5    3.125  3.500  6.250  1.000  0.125  2.875  1.500    2019   G  5-11  175
# 6    3.000  3.375  5.625  1.500  0.125  2.250  1.875    2019   G  5-11  175
# ..     ...    ...    ...    ...    ...    ...    ...     ...  ..   ...  ...
# 527  6.000  8.500  2.000  0.625  0.875  1.750  2.625    2019   C  6-10  220
# 528  4.125  5.750  1.000  0.500  0.875  0.625  3.125    2019   C  6-10  220
# 529  2.250  3.625  0.375  0.125  0.125  0.375  1.875    2019   C  6-10  220
# 530  3.125  4.750  0.750  0.500  0.375  0.500  1.625    2019   C  6-10  220
# 531  1.250  1.750  0.375  0.375  0.250  0.375  1.500    2019   C  6-10  220
#
#            Team_y       Birth City               Draft Status  \
# 2    Anadolu Efes  Cincinnati (OH)         2013 Rnd 1 Pick 18
# 3    Anadolu Efes  Cincinnati (OH)         2013 Rnd 1 Pick 18
# 4    Anadolu Efes  Cincinnati (OH)         2013 Rnd 1 Pick 18
# 5    Anadolu Efes  Cincinnati (OH)         2013 Rnd 1 Pick 18
# 6    Anadolu Efes  Cincinnati (OH)         2013 Rnd 1 Pick 18
# ..            ...              ...                        ...
# 527  Turk Telekom            Konak  2018 NBA Draft, Undrafted
# 528  Turk Telekom            Konak  2018 NBA Draft, Undrafted
# 529  Turk Telekom            Konak  2018 NBA Draft, Undrafted
# 530  Turk Telekom            Konak  2018 NBA Draft, Undrafted
# 531  Turk Telekom            Konak  2018 NBA Draft, Undrafted
#
#              Nationality
# 2    United StatesTurkey
# 3    United StatesTurkey
# 4    United StatesTurkey
# 5    United StatesTurkey
# 6    United StatesTurkey
# ..                   ...
# 527               Turkey
# 528               Turkey
# 529               Turkey
# 530               Turkey
# 531               Turkey
#
# [91 rows x 33 columns]

# %%
merged_df_stats_Croatia['League'] = 'Croatia A1'

# %%
merged_df_stats_Croatia
# Out:
#      Year_x Position   #             Player Team_x    GP     MPG     PPG  \
# 0      2019        G   1   Martin Junakovic    SIB  11.0  39.875  37.125
# 1      2020        G   4   Martin Junakovic    ZAD  16.0  28.750  30.750
# 2      2021        G  10   Martin Junakovic    ZAD  38.0  23.750  25.500
# 3      2022        G   9   Martin Junakovic    ZAD  38.0  28.875  25.750
# 4      2019        G   2  Kresimir Radovcic    ZAB  23.0  34.250  34.375
# ..      ...      ...  ..                ...    ...   ...     ...     ...
# 651    2023        C  19     Emeka Obukwelu   SRKL  12.0  24.875  19.625
# 652    2023        C  20         Ivan Juric    DUB  16.0   7.500  19.500
# 653    2023        C  21       Mario Kresic    RIB   2.0  25.750  17.500
# 654    2023        C  24   Jakov Stipanicev    ZAB  33.0  20.250  14.500
# 655    2023        C  26      Petar Markota    RIB   2.0  22.125  13.500
#
#         FGM     FGA      FG%    3PM    3PA      3P%    FTM     FTA      FT%  \
# 0    12.875  29.875  0.53625  2.375  9.000  0.33000  9.000  10.750  1.05125
# 1    10.375  22.500  0.58000  2.875  9.000  0.40875  7.000   9.500  0.92625
# 2     8.500  20.375  0.52375  2.375  7.750  0.38625  6.000   8.000  0.93750
# 3     9.000  20.750  0.54000  1.750  5.000  0.42250  6.125   8.625  0.89250
# 4    12.250  27.375  0.56000  3.250  9.375  0.42875  6.500   7.750  1.06500
# ..      ...     ...      ...    ...    ...      ...    ...     ...      ...
# 651   7.000  16.125  0.54750  1.500  5.000  0.37500  4.000   5.250  0.95250
# 652   7.500  18.250  0.51750  0.625  1.875  0.41625  3.750   6.875  0.68125
# 653   5.875  17.500  0.41625  2.875  5.875  0.62500  2.875   2.875  1.25000
# 654   4.500  13.625  0.41375  1.625  7.125  0.29250  3.875   5.125  0.92375
# 655   6.750  16.875  0.50000  0.000  0.000  0.00000  0.000   3.375  0.00000
#
#        ORB     DRB     RPG     APG    SPG    BPG    TOV      PF  Year_y Pos  \
# 0    0.875   5.625   6.500  11.750  4.250  0.125  6.875   4.750    2019   G
# 1    1.000   4.750   5.750  11.500  4.375  0.125  6.875   7.375    2019   G
# 2    1.375   3.375   4.625   9.500  2.875  0.125  5.125   7.875    2019   G
# 3    1.375   3.500   4.875  11.750  2.375  0.125  5.000   7.375    2019   G
# 4    1.375   5.750   7.000   8.250  2.625  0.000  5.000   5.000    2020   G
# ..     ...     ...     ...     ...    ...    ...    ...     ...     ...  ..
# 651  2.000  10.500  12.625   2.000  0.000  0.500  3.000   7.250    2022   F
# 652  6.875   8.750  15.750   1.875  1.875  0.625  8.125   9.375    2022   C
# 653  1.500   7.250   8.750   1.500  1.500  2.875  2.875  13.125    2022   C
# 654  3.500   8.625  12.125   2.375  1.625  2.375  3.375   9.375    2022   C
# 655  5.125  13.500  18.625   0.000  0.000  5.125  3.375   8.500    2022   C
#
#        HT   WT             Team_y  Birth City               Draft Status  \
# 0     6-2  195           KK Zadar     Sibenik  2016 NBA Draft, Undrafted
# 1     6-2  195           KK Zadar     Sibenik  2016 NBA Draft, Undrafted
# 2     6-2  195           KK Zadar     Sibenik  2016 NBA Draft, Undrafted
# 3     6-2  195           KK Zadar     Sibenik  2016 NBA Draft, Undrafted
# 4     6-5  194          KK Cibona     Sibenik  2019 NBA Draft, Undrafted
# ..    ...  ...                ...         ...                        ...
# 651   6-8  235        KK Skrljevo  Plano (TX)  2022 NBA Draft, Undrafted
# 652  6-11  229  KK Dubrava Zagreb         NaN    2028 NBA Draft Eligible
# 653   6-7    -  KK Ribola Kastela         NaN    2024 NBA Draft Eligible
# 654  6-11    -           KK Zabok  Novo Mesto  2021 NBA Draft, Undrafted
# 655   6-7    -  KK Ribola Kastela         NaN    2025 NBA Draft Eligible
#
#        Nationality      League
# 0          Croatia  Croatia A1
# 1          Croatia  Croatia A1
# 2          Croatia  Croatia A1
# 3          Croatia  Croatia A1
# 4          Croatia  Croatia A1
# ..             ...         ...
# 651  United States  Croatia A1
# 652        Croatia  Croatia A1
# 653        Croatia  Croatia A1
# 654       Slovenia  Croatia A1
# 655        Croatia  Croatia A1
#
# [656 rows x 34 columns]

# %%
merged_df_stats_Croatia.to_csv('DataFiles/euroleague_stats_Croatia_merged.csv', index=False)

# %%
merged_df_stats_Croatia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year_x        656 non-null    int64
#  1   Position      656 non-null    object
#  2   #             656 non-null    int64
#  3   Player        656 non-null    object
#  4   Team_x        656 non-null    object
#  5   GP            656 non-null    float64
#  6   MPG           656 non-null    float64
#  7   PPG           656 non-null    float64
#  8   FGM           656 non-null    float64
#  9   FGA           656 non-null    float64
#  10  FG%           656 non-null    float64
#  11  3PM           656 non-null    float64
#  12  3PA           656 non-null    float64
#  13  3P%           656 non-null    float64
#  14  FTM           656 non-null    float64
#  15  FTA           656 non-null    float64
#  16  FT%           656 non-null    float64
#  17  ORB           656 non-null    float64
#  18  DRB           656 non-null    float64
#  19  RPG           656 non-null    float64
#  20  APG           656 non-null    float64
#  21  SPG           656 non-null    float64
#  22  BPG           656 non-null    float64
#  23  TOV           656 non-null    float64
#  24  PF            656 non-null    float64
#  25  Year_y        656 non-null    int64
#  26  Pos           656 non-null    object
#  27  HT            656 non-null    object
#  28  WT            656 non-null    object
#  29  Team_y        656 non-null    object
#  30  Birth City    479 non-null    object
#  31  Draft Status  656 non-null    object
#  32  Nationality   656 non-null    object
#  33  League        656 non-null    object
# dtypes: float64(20), int64(3), object(11)
# memory usage: 174.4+ KB
