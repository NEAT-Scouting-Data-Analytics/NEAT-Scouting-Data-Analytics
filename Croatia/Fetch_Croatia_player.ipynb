# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

years = list(range(2019, 2024))


#url_start = 'https://basketball.realgm.com/international/league/12/French-Jeep-Elite/stats/{year}/Per_48/Qualified/All/points/{position}/desc/1/Regular_Season'
url_start = 'https://basketball.realgm.com/international/league/14/Croatian-A-1-Liga/players/{}/{}'
data = []  # List to store parsed data
index = ['762','863','952','1046','1141']


for index, year in zip(index, years):
    url = url_start.format(index, year)  # Properly formatted URL
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    rows = soup.select('.tablesaw tbody tr')
    print(f"Year: {year}, Rows: {len(rows)}")  # Debugging print

    for row in rows:
        player = [year]  # Add the year and position to the player data
        player += [cell.text.strip() for cell in row.find_all('td')]
        data.append(player)



columns = ['Year'] + [header.text.strip() for header in soup.select('.tablesaw thead th')]

print("Columns:", columns)
print("Number of columns:", len(columns))

# Creating DataFrame from the collected data
df_croatia_players = pd.DataFrame(data, columns=columns)

# Creating DataFrame from the collected data
#columns = ['Year', 'Position', '#', 'Player', 'Team', 'GP', 'MPG', 'PPG', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
           #'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'RPG', 'APG', 'SPG', 'BPG', 'TOV', 'PF']
#df_croatia_players = pd.DataFrame(data)

df_croatia_players['Pos'] = df_croatia_players['Pos'].replace(['PG', 'SG'], 'G')
df_croatia_players['Pos'] = df_croatia_players['Pos'].replace(['SF', 'PF'], 'F')


# Save DataFrame to a CSV file
df_croatia_players.to_csv('DataFiles/euroleague_stats_Croatia_player.csv', index=False)


# Display DataFrame
df_croatia_players
# Out:
# Year: 2019, Rows: 207
# Year: 2020, Rows: 215
# Year: 2021, Rows: 238
# Year: 2022, Rows: 215
# Year: 2023, Rows: 222
# Columns: ['Year', 'Player', 'Pos', 'HT', 'WT', 'Team', 'Birth City', 'Draft Status', 'Nationality']
# Number of columns: 9
#       Year           Player Pos    HT   WT                 Team  \
# 0     2019     Bashir Ahmed   F   6-7  210             KK Zadar
# 1     2019      Byron Allen   C   6-7  275             KK Zadar
# 2     2019  Andro Anzulovic   G   6-4  200             KK Zabok
# 3     2019   Roko Anzulovic   G   6-5    -  KK Hermes Znalitica
# 4     2019      Marko Atelj  GF   6-5  205   KK Sonik Puntamika
# ...    ...              ...  ..   ...  ...                  ...
# 1092  2023       Tonko Vuko   F   6-8  228             KK Split
# 1093  2023  Domagoj Vukovic   F  6-10    -            KK Cibona
# 1094  2023   Kahlil Whitney   F   6-6  210          KK Skrljevo
# 1095  2023     Karlo Zganec   F   6-9  225             KK Zadar
# 1096  2023     Matija Zoric   C   6-9    -         KK Dubrovnik
#
#          Birth City               Draft Status    Nationality
# 0     New York (NY)  2018 NBA Draft, Undrafted  United States
# 1       Leland (MS)  2006 NBA Draft, Undrafted  United States
# 2            Zagreb  2013 NBA Draft, Undrafted        Croatia
# 3               N/A  2018 NBA Draft, Undrafted        Croatia
# 4             Zadar  2013 NBA Draft, Undrafted        Croatia
# ...             ...                        ...            ...
# 1092          Split  2017 NBA Draft, Undrafted        Croatia
# 1093         Rijeka  2015 NBA Draft, Undrafted        Croatia
# 1094   Chicago (IL)  2020 NBA Draft, Undrafted  United States
# 1095         Zagreb  2017 NBA Draft, Undrafted        Croatia
# 1096            N/A    2027 NBA Draft Eligible        Croatia
#
# [1097 rows x 9 columns]

# %%
#pd.set_option('display.max_rows', None)

# %%
df_croatia_players[df_croatia_players['Player'] == 'Karlo Zganec']
# Out:
#       Year        Player Pos   HT   WT      Team Birth City  \
# 657   2021  Karlo Zganec   F  6-9  225  KK Split     Zagreb
# 873   2022  Karlo Zganec   F  6-9  225  KK Zadar     Zagreb
# 1095  2023  Karlo Zganec   F  6-9  225  KK Zadar     Zagreb
#
#                    Draft Status Nationality
# 657   2017 NBA Draft, Undrafted     Croatia
# 873   2017 NBA Draft, Undrafted     Croatia
# 1095  2017 NBA Draft, Undrafted     Croatia

# %%
df_turkey_players

# %%
#renaming positions
df['Position'] = df['Position'].replace(['PG', 'SG'], 'G')
df['Position'] = df['Position'].replace(['SF', 'PF'], 'F')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #renaming positions
# ----> 2 df['Position'] = df['Position'].replace(['PG', 'SG'], 'G')
#       3 df['Position'] = df['Position'].replace(['SF', 'PF'], 'F')
#
# NameError: name 'df' is not defined

# %%
#calculation for 100 possessions
df.loc[:, 'GP':] = df.loc[:,'GP':].astype(float)
df.loc[:, 'MPG':] = df.loc[:,'MPG':].mul(1.25)

# %%
def feet_to_meters(height):
    if isinstance(height, str):  # Check if height is a string
        try:
            feet, inches = map(int, height.split('-'))
            total_feet = feet + inches / 12  # Convert inches to feet
            total_meters = total_feet * 0.3048  # Convert feet to meters
            return round(total_meters, 2)  # Round to 2 decimals
        except (ValueError, AttributeError):
            return None  # Return None if there's an error in conversion or attribute access
    else:
        return None

# %%
df_turkey_players

# %%
df_turkey_players['HT'] = df_turkey_players['HT'].apply(feet_to_meters)

# %%
df_turkey_players

# %%
pd.set_option('display.max_rows', None)

# %%
df_turkey_players

# %%
df_turkey_players

# %%
def feet_to_meters(height):
    if isinstance(height, str):
        feet, inches = map(int, height.split('-'))
        total_feet = feet + inches / 12  # Convert inches to feet
        total_meters = total_feet * 0.3048  # Convert feet to meters
        return round(total_meters, 2)  # Round to 2 decimals
    else:
        return None

# %%
#filtering for center
#df_center = df[df['Position'] == 'C']
#df_center_filtered = df_center[(df_center['RPG'] >= 13.0) & (df_center['BPG'] >= 2.0 ) & (df_center['APG'] >= 3.0)]
