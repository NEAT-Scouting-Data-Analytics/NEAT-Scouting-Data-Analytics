# %% [markdown]
# ## Scraping 'Player Index' data in order to access player´s positions and be able to merge with other DF later on.

# %%
import pandas as pd
import requests
pd.set_option('display.max_columns', None) # so we can see all columns in a wide DataFrame
import time
import numpy as np

# %%
headers_bio = {
    'Accept': '*/*', 
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'de-DE,de;q=0.9,en-US;q=0.8,en;q=0.7',
    'Connection': 'keep-alive',
    'Host': 'stats.nba.com',
    'Origin': 'https://www.nba.com',
    'Referer': 'https://www.nba.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-site',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:123.0) Gecko/20100101 Firefox/123.0'
}

# %%
# Scraping data from 'Player Index' 
raw_api_index = "https://stats.nba.com/stats/playerindex?College=&Country=&DraftPick=&DraftRound=&DraftYear=&Height=&Historical=1&LeagueID=00&Season=2023-24&SeasonType=Regular%20Season&TeamID=0&Weight="

# Using requests to access the JSON
r_index = requests.get(url=raw_api_index, headers=headers_bio).json()

# Accessing the column names and data in JSON
df_cols_short_index = r_index['resultSets'][0]['headers']
data_bio_index = r_index['resultSets'][0]['rowSet']

# %%
# Defining list of European countries
european_counties = ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia', 'Denmark','Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland',
'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands','Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Serbia', 'Ukraine', 'Russia', 'Turkey', 'Georgia','Bosnia and Herzegovina', 'Kosovo', 'Belarus', 'Albania', 'Armenia' ]

# Converting JSON into pandas DF
data_link = pd.DataFrame(data_bio_index, columns=df_cols_short_index)

# Filtering out players who played from 1996 and only from European countries
data_link_filtered = data_link[(data_link['TO_YEAR'] >= '1996') & (data_link['COUNTRY'].isin(european_counties))]

# %%
# Calling dataframe 
data_link_filtered.head(40)
# Out:
#      PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME               PLAYER_SLUG  \
# 4         1505      Abdul-Wahad             Tariq         tariq-abdul-wahad
# 9       203518          Abrines              Alex              alex-abrines
# 34      201582           Ajinca            Alexis             alexis-ajinca
# 41     1630583           Aldama             Santi              santi-aldama
# 42      203128          Aldemir            Furkan            furkan-aldemir
# 106     101149  Andriuskevicius          Martynas  martynas-andriuskevicius
# 111     203507    Antetokounmpo           Giannis     giannis-antetokounmpo
# 112    1628961    Antetokounmpo            Kostas      kostas-antetokounmpo
# 113     203648    Antetokounmpo          Thanasis    thanasis-antetokounmpo
# 145     201600             Asik              Omer                 omer-asik
# 164    1630555            Ayayi              Joel                joel-ayayi
# 177       2053          Bagaric           Dalibor           dalibor-bagaric
# 213     200745         Bargnani            Andrea           andrea-bargnani
# 264     201587            Batum           Nicolas             nicolas-batum
# 282     201958         Beaubois          Rodrigue         rodrigue-beaubois
# 292     201158        Belinelli             Marco           marco-belinelli
# 303    1627733           Bender            Dragan             dragan-bender
# 323    1629541          Bertans            Dairis            dairis-bertans
# 324     202722          Bertans             Davis             davis-bertans
# 336       2740         Biedrins            Andris           andris-biedrins
# 348    1629048          Bitadze              Goga              goga-bitadze
# 349    1641931            Bitim           Onuralp             onuralp-bitim
# 351     202357          Bjelica           Nemanja           nemanja-bjelica
# 391     203992       Bogdanovic            Bogdan         bogdan-bogdanovic
# 392     202711       Bogdanovic             Bojan          bojan-bogdanovic
# 402    1627762         Bolomboy              Joel             joel-bolomboy
# 409    1629067            Bonga             Isaac               isaac-bonga
# 494       2056           Brezec            Primoz             primoz-brezec
# 603       2469            Burke               Pat                 pat-burke
# 642       2560        Cabarkapa             Zarko           zarko-cabarkapa
# 651     101181         Calderon              Jose             jose-calderon
# 663    1641739           Camara           Toumani            toumani-camara
# 670    1628427           Cancar            Vlatko             vlatko-cancar
# 729    1630608          Cazalon           Malcolm           malcolm-cazalon
# 777    1631321          Cissoko              Sidy              sidy-cissoko
# 789     201964           Claver            Victor             victor-claver
# 877    1627822         Cornelie              Petr             petr-cornelie
# 885    1641731        Coulibaly             Bilal           bilal-coulibaly
# 964        390        Danilovic             Sasha           sasha-danilovic
# 972     203540           Datome              Gigi               gigi-datome
#
#         TEAM_ID  TEAM_SLUG  IS_DEFUNCT      TEAM_CITY      TEAM_NAME  \
# 4    1610612758      kings           0     Sacramento          Kings
# 9    1610612760    thunder           0  Oklahoma City        Thunder
# 34   1610612740   pelicans           0    New Orleans       Pelicans
# 41   1610612763  grizzlies           0        Memphis      Grizzlies
# 42   1610612755     sixers           0   Philadelphia          76ers
# 106  1610612739  cavaliers           0      Cleveland      Cavaliers
# 111  1610612749      bucks           0      Milwaukee          Bucks
# 112  1610612741      bulls           0        Chicago          Bulls
# 113  1610612749      bucks           0      Milwaukee          Bucks
# 145  1610612740   pelicans           0    New Orleans       Pelicans
# 164  1610612764    wizards           0     Washington        Wizards
# 177  1610612741      bulls           0        Chicago          Bulls
# 213  1610612761    raptors           0        Toronto        Raptors
# 264  1610612755     sixers           0   Philadelphia          76ers
# 282  1610612742  mavericks           0         Dallas      Mavericks
# 292  1610612759      spurs           0    San Antonio          Spurs
# 303  1610612756       suns           0        Phoenix           Suns
# 323  1610612740   pelicans           0    New Orleans       Pelicans
# 324  1610612766    hornets           0      Charlotte        Hornets
# 336  1610612744   warriors           0   Golden State       Warriors
# 348  1610612753      magic           0        Orlando          Magic
# 349  1610612741      bulls           0        Chicago          Bulls
# 351  1610612744   warriors           0   Golden State       Warriors
# 391  1610612737      hawks           0        Atlanta          Hawks
# 392  1610612752     knicks           0       New York         Knicks
# 402  1610612762       jazz           0           Utah           Jazz
# 409  1610612761    raptors           0        Toronto        Raptors
# 494  1610612766    hornets           0      Charlotte        Hornets
# 603  1610612756       suns           0        Phoenix           Suns
# 642  1610612744   warriors           0   Golden State       Warriors
# 651  1610612761    raptors           0        Toronto        Raptors
# 663  1610612757    blazers           0       Portland  Trail Blazers
# 670  1610612743    nuggets           0         Denver        Nuggets
# 729  1610612765    pistons           0        Detroit        Pistons
# 777  1610612759      spurs           0    San Antonio          Spurs
# 789  1610612757    blazers           0       Portland  Trail Blazers
# 877  1610612743    nuggets           0         Denver        Nuggets
# 885  1610612764    wizards           0     Washington        Wizards
# 964  1610612748       heat           0          Miami           Heat
# 972  1610612765    pistons           0        Detroit        Pistons
#
#     TEAM_ABBREVIATION JERSEY_NUMBER POSITION HEIGHT WEIGHT  \
# 4                 SAC             9      F-G    6-6    235
# 9                 OKC             8        G    6-6    190
# 34                NOP            42        C    7-2    248
# 41                MEM             7      F-C    7-0    215
# 42                PHI            19      F-C   6-10    240
# 106               CLE            15        C    7-2    240
# 111               MIL            34        F   6-11    243
# 112               CHI            37        F   6-10    200
# 113               MIL            43        F    6-7    219
# 145               NOP             3        C    7-0    255
# 164               WAS            17        G    6-4    180
# 177               CHI            11        C    7-1    290
# 213               TOR            77      C-F    7-0    245
# 264               PHI            40      G-F    6-8    230
# 282               DAL             3        G    6-2    185
# 292               SAS            18        G    6-5    220
# 303               PHX            35        F    7-1    225
# 323               NOP             9        G    6-4    200
# 324               CHA             9        F   6-10    225
# 336               GSW            15        C    7-0    242
# 348               ORL            35      C-F   6-10    250
# 349               CHI            17        F    6-6    215
# 351               GSW             8        F    6-9    234
# 391               ATL            13        G    6-5    225
# 392               NYK            44        F    6-7    226
# 402               UTA            21        F    6-9    235
# 409               TOR            17        G    6-8    180
# 494               CHA             9        C    7-1    255
# 603               PHX            11      C-F   6-11    250
# 642               GSW            11      F-C   6-11    230
# 651               TOR            81        G    6-3    200
# 663               POR            33        F    6-7    226
# 670               DEN            31        F    6-8    236
# 729               DET            20        G    6-6    185
# 777               SAS            25        G    6-6    200
# 789               POR            18        F    6-9    224
# 877               DEN            21        F   6-11    220
# 885               WAS             0        G    6-8    195
# 964               MIA             5        G    6-6    200
# 972               DET            70        F    6-8    215
#
#                  COLLEGE    COUNTRY  DRAFT_YEAR  DRAFT_ROUND  DRAFT_NUMBER  \
# 4         San Jose State     France      1997.0          1.0          11.0
# 9           FC Barcelona      Spain      2013.0          2.0          32.0
# 34         Hyeres-Toulon     France      2008.0          1.0          20.0
# 41       Loyola-Maryland      Spain      2021.0          1.0          30.0
# 42           Galatasaray     Turkey      2012.0          2.0          53.0
# 106             Zalgiris  Lithuania      2005.0          2.0          44.0
# 111        Filathlitikos     Greece      2013.0          1.0          15.0
# 112               Dayton     Greece      2018.0          2.0          60.0
# 113        Panathinaikos     Greece      2014.0          2.0          51.0
# 145           Fenerbahce     Turkey      2008.0          2.0          36.0
# 164              Gonzaga     France         NaN          NaN           NaN
# 177       Benston Zagreb    Croatia      2000.0          1.0          24.0
# 213     Benetton Treviso      Italy      2006.0          1.0           1.0
# 264              Le Mans     France      2008.0          1.0          25.0
# 282               Cholet     France      2009.0          1.0          25.0
# 292    Fortitudo Bologna      Italy      2007.0          1.0          18.0
# 303     Maccabi Tel Aviv    Croatia      2016.0          1.0           4.0
# 323       Olimpia Milano     Latvia         NaN          NaN           NaN
# 324             Baskonia     Latvia      2011.0          2.0          42.0
# 336            BK Skonto     Latvia      2004.0          1.0          11.0
# 348          Mega Basket    Georgia      2019.0          1.0          18.0
# 349            Bursaspor     Turkey         NaN          NaN           NaN
# 351           Fenerbahce     Serbia      2010.0          2.0          35.0
# 391           Fenerbahce     Serbia      2014.0          1.0          27.0
# 392           Fenerbahce    Croatia      2011.0          2.0          31.0
# 402          Weber State    Ukraine      2016.0          2.0          52.0
# 409  Skyliners Frankfurt    Germany      2018.0          2.0          39.0
# 494       Union Olimpija   Slovenia      2000.0          1.0          27.0
# 603               Auburn    Ireland         NaN          NaN           NaN
# 642            Buducnost     Serbia      2003.0          1.0          17.0
# 651         Tau Ceramica      Spain         NaN          NaN           NaN
# 663               Dayton    Belgium      2023.0          2.0          52.0
# 670     San Pablo Burgos   Slovenia      2017.0          2.0          49.0
# 729          Mega Basket     France         NaN          NaN           NaN
# 777  NBA G League Ignite     France      2023.0          2.0          44.0
# 789             Valencia      Spain      2009.0          1.0          22.0
# 877           Pau Orthez     France      2016.0          2.0          53.0
# 885     Metropolitans 92     France      2023.0          1.0           7.0
# 964       Virtus Bologna     Serbia      1992.0          2.0          43.0
# 972          Virtus Roma      Italy         NaN          NaN           NaN
#
#      ROSTER_STATUS   PTS   REB  AST STATS_TIMEFRAME FROM_YEAR TO_YEAR
# 4              NaN   7.8   3.3  1.1          Career      1997    2003
# 9              NaN   5.3   1.4  0.5          Career      2016    2018
# 34             NaN   5.3   3.9  0.5          Career      2008    2017
# 41             1.0  10.7   5.8  2.3          Season      2021    2023
# 42             NaN   2.3   4.3  0.7          Career      2014    2014
# 106            NaN   0.0   0.7  0.0          Career      2005    2006
# 111            1.0  30.8  11.5  6.4          Season      2013    2023
# 112            NaN   1.0   1.0  0.1          Career      2018    2020
# 113            1.0   0.9   0.4  0.5          Season      2015    2023
# 145            NaN   5.3   7.1  0.6          Career      2010    2017
# 164            NaN   0.3   0.4  0.6          Career      2021    2021
# 177            NaN   2.6   2.5  0.4          Career      2000    2002
# 213            NaN  14.3   4.6  1.2          Career      2006    2015
# 264            1.0   5.4   4.2  2.1          Season      2008    2023
# 282            NaN   7.1   1.9  2.1          Career      2009    2012
# 292            NaN   9.7   2.1  1.7          Career      2007    2019
# 303            NaN   5.4   3.9  1.3          Career      2016    2019
# 323            NaN   2.8   0.8  0.8          Career      2018    2018
# 324            1.0   6.2   1.3  0.8          Season      2016    2023
# 336            NaN   6.3   7.0  0.9          Career      2004    2013
# 348            1.0   5.3   4.9  1.4          Season      2019    2023
# 349            1.0   3.7   1.6  0.7          Season      2023    2023
# 351            NaN   7.6   4.6  1.8          Career      2015    2021
# 391            1.0  17.0   3.5  3.1          Season      2017    2023
# 392            1.0  15.9   2.8  1.9          Season      2014    2023
# 402            NaN   1.7   1.5  0.1          Career      2016    2017
# 409            NaN   3.1   2.2  0.8          Career      2018    2021
# 494            NaN   7.2   3.9  0.5          Career      2001    2009
# 603            NaN   3.7   2.1  0.3          Career      2002    2006
# 642            NaN   4.3   2.1  0.6          Career      2003    2006
# 651            NaN   8.9   2.4  5.8          Career      2005    2018
# 663            1.0   7.5   4.9  1.2          Season      2023    2023
# 670            1.0   3.5   1.7  0.9          Career      2019    2023
# 729            NaN   0.0   0.0  0.0          Season      2023    2023
# 777            1.0   1.0   1.0  0.0          Season      2023    2023
# 789            NaN   3.2   2.2  0.7          Career      2012    2014
# 877            NaN   1.1   1.1  0.2          Career      2021    2021
# 885            1.0   8.4   4.1  1.7          Season      2023    2023
# 964            NaN  12.8   2.4  2.0          Career      1995    1996
# 972            NaN   3.4   1.4  0.4          Career      2013    2014
