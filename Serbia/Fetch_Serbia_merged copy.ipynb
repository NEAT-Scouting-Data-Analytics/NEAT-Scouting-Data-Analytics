# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
#Import dataframes 

df_stats_Serbia = pd.read_csv('DataFiles/euroleague_stats_Serbia.csv')
df_player_stats_Serbia= pd.read_csv('DataFiles/euroleague_stats_Serbia_player.csv')

# %%
df_player_stats_Serbia.nunique()
# Out:
# Year              5
# Player          358
# Pos               6
# HT               19
# WT               64
# Team             21
# Birth City      123
# Draft Status     44
# Nationality      42
# dtype: int64

# %%
df_player_stats_Serbia=df_player_stats_Serbia.drop_duplicates(subset=['Player'])

# %%
df_player_stats_Serbia
# Out:
#      Year                 Player Pos    HT   WT                      Team  \
# 0    2011            Stefan Agoc   F   6-7  210                KK Dynamic
# 1    2011      Luka Aksentijevic  GF   6-5    -          KK Sloboda Uzice
# 2    2011        Danilo Andjusic   G   6-4  200               KK Partizan
# 3    2011  Aleksandar Andrejevic   C  6-11  260      KK Zdravlje Leskovac
# 4    2011      Stefan Andrejevic   C   6-9  210            OKK Novi Pazar
# ..    ...                    ...  ..   ...  ...                       ...
# 353  2011      Bogdan Zagradanin   F   6-6    -     KK Vojvodina Novi Sad
# 354  2011          Adi Zahiragic   G   6-1  165         Zlatibor Cajetina
# 355  2011        Balsa Zivanovic   G   6-3    -               FMP Beograd
# 356  2011         Marko Zivkovic   -   6-7    -               OKK Beograd
# 357  2011      Petar Zivojinovic   F   6-7    -  KK Mladost Admiral Zemun
#
#     Birth City               Draft Status             Nationality
# ...

# %%
# columns_to_delete = ['PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2', 'TD3', 'WNBA_FANTASY_PTS', 'GP_RANK',
#                      'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK',
#                      'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK',
#                      'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK',
#                      'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK',
#                      'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK',
#                      'DD2_RANK', 'TD3_RANK', 'WNBA_FANTASY_PTS_RANK']

# # Delete the specified columns
# df_player_stats.drop(columns=columns_to_delete, inplace=True, errors='ignore')

# df_player_stats.rename(columns={'Season_type': 'Season'}, inplace=True)

# %%
# Merge 'df_player_stats' and ‘df_bio‘ on common keys ‘PLAYER_ID‘ and ‘Year‘ in order to get 'COUNTRY' column.
merged_df_stats_Serbia = pd.merge(df_stats_Serbia, df_player_stats_Serbia, on=['Player'], how='inner')

#columns_to_delete_merged = ['GP_y','PTS_y','REB_y','AST_y','NET_RATING','OREB_PCT','DREB_PCT','USG_PCT', 'TS_PCT','AST_PCT']

#merged_df_stats_bio.drop(columns=columns_to_delete_merged, inplace=True)

# %%
# Checking the result of 'merged_df_stats_bio'
merged_df_stats_Serbia
# Out:
#      Year_x Position   #               Player Team_x    GP     MPG     PPG  \
# 0      2019        G  13     Aleksa Uskokovic    FMP  11.0  30.750  14.500
# 1      2023        G  16     Aleksa Uskokovic    MEG   8.0  38.000  14.125
# 2      2019        G  17      Mihailo Jovicic    BEO  24.0  34.625  12.375
# 3      2020        G  13      Mihailo Jovicic    BEO  25.0  40.000  14.000
# 4      2019        G  25  Milos Milisavljevic   DYNA   3.0  23.750   7.125
# ..      ...      ...  ..                  ...    ...   ...     ...     ...
# 319    2023        C  31    Aleksa Milenkovic    BEO  35.0  14.000   5.375
# 320    2023        C  33      Filip Radakovic    ZEM  21.0  16.750   4.375
# 321    2023        C  34       Milan Pavlovic    PAZ  26.0  11.375   3.875
# 322    2023        C  35      Filip Malesevic   DYNA  12.0   8.875   3.000
# 323    2023        C  40      Lazar Milosevic   ZLAT  11.0   3.500   0.500
#
# ...

# %%
merged_df_stats_Serbia[merged_df_stats_Serbia['Player'] == 'Mihailo Jovicic']
# Out:
#    Year_x Position   #           Player Team_x    GP     MPG     PPG    FGM  \
# 2    2019        G  17  Mihailo Jovicic    BEO  24.0  34.625  12.375  4.375
# 3    2020        G  13  Mihailo Jovicic    BEO  25.0  40.000  14.000  4.750
#
#       FGA      FG%    3PM   3PA      3P%    FTM    FTA      FT%   ORB    DRB  \
# 2   9.875  0.56250  1.125  3.25  0.42375  2.375  3.125  0.95875  0.50  3.750
# 3  12.500  0.46875  1.500  4.25  0.42125  3.125  4.375  0.89125  0.75  4.625
#
#      RPG   APG    SPG  BPG    TOV    PF  Year_y Pos   HT   WT  \
# 2  4.375  5.25  1.750  0.0  2.375  2.25    2011   G  6-2  194
# 3  5.250  5.25  1.875  0.0  3.000  2.25    2011   G  6-2  194
#
#                Team_y  Birth City               Draft Status Nationality
# 2  KK Vrsac Swisslion  Kragujevac  2021 NBA Draft, Undrafted      Serbia
# 3  KK Vrsac Swisslion  Kragujevac  2021 NBA Draft, Undrafted      Serbia

# %%
merged_df_stats_Serbia[merged_df_stats_Serbia.groupby('Player').transform('size')>4]
# Out:
#     Year_x Position   #             Player Team_x    GP     MPG     PPG  \
# 16    2019        G  15    Stefan Mitrovic    TAM  33.0  25.750  12.875
# 17    2020        G   9    Stefan Mitrovic   ZLAT  25.0  30.375  13.750
# 18    2021        G  24    Stefan Mitrovic   ZLAT  27.0  24.375  10.000
# 19    2022        F  15    Stefan Mitrovic   RADN  24.0  28.500  13.750
# 20    2023        G  36    Stefan Mitrovic    NOV  33.0  18.625   6.875
# 25    2019        G  25      Luka Mitrovic   SWIS  13.0  23.250   7.750
# 26    2020        G   3      Luka Mitrovic    DUN  26.0  34.875  20.250
# 27    2021        G  35      Luka Mitrovic    ZEM  25.0  18.375   7.250
# 28    2022        G   3      Luka Mitrovic    BEO  28.0  35.000  19.000
# 29    2022        F  23      Luka Mitrovic    ZVE   5.0  18.000  10.250
# 30    2023        F   2      Luka Mitrovic    ZVE   2.0  25.750  23.125
# 31    2019        F   2     Ivan Smiljanic    TAM  36.0  38.250  19.875
# ...

# %%
merged_df_stats_Serbia['League'] = 'Serbian KLS'

# %%
merged_df_stats_Serbia
# Out:
#      Year_x Position   #               Player Team_x    GP     MPG     PPG  \
# 0      2019        G  13     Aleksa Uskokovic    FMP  11.0  30.750  14.500
# 1      2023        G  16     Aleksa Uskokovic    MEG   8.0  38.000  14.125
# 2      2019        G  17      Mihailo Jovicic    BEO  24.0  34.625  12.375
# 3      2020        G  13      Mihailo Jovicic    BEO  25.0  40.000  14.000
# 4      2019        G  25  Milos Milisavljevic   DYNA   3.0  23.750   7.125
# ..      ...      ...  ..                  ...    ...   ...     ...     ...
# 319    2023        C  31    Aleksa Milenkovic    BEO  35.0  14.000   5.375
# 320    2023        C  33      Filip Radakovic    ZEM  21.0  16.750   4.375
# 321    2023        C  34       Milan Pavlovic    PAZ  26.0  11.375   3.875
# 322    2023        C  35      Filip Malesevic   DYNA  12.0   8.875   3.000
# 323    2023        C  40      Lazar Milosevic   ZLAT  11.0   3.500   0.500
#
# ...

# %%
merged_df_stats_Serbia.to_csv('DataFiles/euroleague_stats_Serbia_merged.csv', index=False)
