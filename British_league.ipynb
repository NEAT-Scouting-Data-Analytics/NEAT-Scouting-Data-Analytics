# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
years = list(range(2011, 2024))
url_start = 'https://basketball.realgm.com/international/league/69/British-BBL/stats/{year}/Per_48/Qualified/All/points/{position}/desc/1/Regular_Season'
data = []  # List to store parsed data
for year in years:
    for position in ['PG', 'SG', 'SF', 'PF', 'C']:
        url = url_start.format(year=year, position=position)  # Correctly format the URL
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        for row in soup.select('.tablesaw tbody tr'):
            player = [year, position]  # Add the year and position to the player data
            player += [cell.text.strip() for cell in row.find_all('td')]
            data.append(player)
# Creating DataFrame from the collected data
columns = ['Year', 'Position', '#', 'Player', 'Team', 'GP', 'MPG', 'PPG', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
           'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'RPG', 'APG', 'SPG', 'BPG', 'TOV', 'PF']
df = pd.DataFrame(data, columns=columns)
# Save DataFrame to a CSV file
df.to_csv('british_stats_with_positions.csv', index=False)
# Display DataFrame
df
# Out:
#       Year Position   #              Player Team  GP   MPG   PPG   FGM   FGA  \
# 0     2012       PG   1     Cameron Rundles  LEI  35  33.7  27.7  10.5  23.2
# 1     2012       PG   2          Paul Gause  NEW  32  25.2  26.7   9.8  21.3
# 2     2012       PG   3         Jeremy Bell  UCP  32  36.6  25.3   9.2  21.9
# 3     2012       PG   4     Jimmy Langhurst  OHS  27  35.5  24.9   8.3  17.6
# 4     2012       PG   5          Adam Brown  CHE  33  38.5  24.6   9.7  21.9
# ...    ...      ...  ..                 ...  ...  ..   ...   ...   ...   ...
# 1018  2023        C  18     Donovan Johnson  NEW  14  21.0  16.5   5.1  13.9
# 1019  2023        C  19       Hasahn French  NEW  25  25.1  13.9   6.5  13.5
# 1020  2023        C  20  Michael Ochereobia  CHE  24  18.3  12.6   5.8  10.2
# 1021  2023        C  21    Jonathan Komagum  LON  24  14.0  10.5   3.6   9.0
# 1022  2023        C  22        Samuel Keita  PLY  34   7.2   9.8   3.3   8.2
#
# ...

# %%
https://basketball.realgm.com/international/league/69/British-BBL/players{}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
years = list(range(2011, 2024))
url_start = "https://basketball.realgm.com/international/league/8/Greek-HEBA-A1/players/{}/{}"
data = []  # List to store parsed data
# index = [ '', '', '', '', '',]
for year in years:
    for position in ['1085', '993', '904', '803', '702']:
        url = url_start.format(year=year, position=position)  # Correctly format the URL
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        for row in soup.select('.tablesaw tbody tr'):
            player = [year, position]  # Add the year and position to the player data
            player += [cell.text.strip() for cell in row.find_all('td')]
            data.append(player)
# Creating DataFrame from the collected data
columns = ['Year', 'Position', '#', 'Player', 'Team', 'GP', 'MPG', 'PPG', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
           'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'RPG', 'APG', 'SPG', 'BPG', 'TOV', 'PF']
df = pd.DataFrame(data, columns=columns)
# Save DataFrame to a CSV file
df.to_csv('british_stats_with_positions.csv', index=False)
# Display DataFrame
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[53], line 10
#       8 for year in years:
#       9     for position in ['1085', '993', '904', '803', '702']:
# ---> 10         url = url_start.format(year=year, position=position)  # Correctly format the URL
#      11         response = requests.get(url)
#      12         soup = BeautifulSoup(response.content, 'html.parser')
#
# IndexError: Replacement index 0 out of range for positional args tuple

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

years = list(range(2011, 2024))
url_start = "https://basketball.realgm.com/international/league/8/Greek-HEBA-A1/players/{}/{}"
data = []  # List to store parsed data

for year in years:
    for position in ['1085', '993', '904', '803', '702']:
        url = url_start.format(year, position)  # Correctly format the URL
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        for row in soup.select('.tablesaw tbody tr'):
            player_data = [year, position]  # Add the year and position to the player data
            player_data += [cell.text.strip() for cell in row.find_all('td')]
            data.append(player_data)

# Creating DataFrame from the collected data
columns = ['Pos', 'HT', 'WT', 'Team', 'Birth City', 'Draft Status', 'Nationality']

df = pd.DataFrame(data, columns=columns)

# Save DataFrame to a CSV file
df.to_csv('greek_heba_a1_stats_with_new_columns.csv', index=False)

# Display DataFrame
df
# Out:
# Empty DataFrame
# Columns: [Pos, HT, WT, Team, Birth City, Draft Status, Nationality]
# Index: []

# %%
british_stats_with_positions = df

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Initialize empty list to store data
all_data = []

# Define the range of seasons (from 2011-2012 to 2022-2023)
start_year = 2011
end_year = 2022

# Loop through each season
for year in range(start_year, end_year + 1):
    season_start_year = year
    season_end_year = year + 1
    
    # Construct the URL for the current season
    url = f'https://basketball.realgm.com/international/league/69/British-BBL/players/{season_start_year}-{season_end_year}'
    
    # Send a GET request to the URL
    response = requests.get(url)
    
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find the table containing player data
        table = soup.find('table', class_='tablesaw')
        
        # Extract column names
        columns = [th.text.strip() for th in table.find_all('th')]
        
        # Initialize data list to store parsed data for the current season
        data = []
        
        # Extract player data row by row
        for row in table.find_all('tr')[1:]:
            player_data = [td.text.strip() for td in row.find_all('td')]
            data.append(player_data)
        
        # Create DataFrame from the collected data for the current season
        df = pd.DataFrame(data, columns=columns)
        
        # Add a column for the season
        df['Season'] = f'{season_start_year}-{season_end_year}'
        
        # Append the DataFrame for the current season to the list
        all_data.append(df)
    
# Concatenate all DataFrames into one
merged_df = pd.concat(all_data, ignore_index=True)

# Save DataFrame to a CSV file
merged_df.to_csv('british_bio_players.csv', index=False)

# Display DataFrame
merged_df

# %%
british_bio_bbl_players = merged_df

# %%
british_bio_bbl_players.nunique()
# Out:
# Player          147
# Pos              10
# HT               17
# WT               45
# Team             10
# Birth City      113
# Draft Status     21
# Nationality      21
# Season           12
# dtype: int64

# %%
import pandas as pd

# Load the datasets
british_stats_df = pd.read_csv('/Users/allendcosta/NBA-NEAT/NEAT-Scouting-Data-Analytics/DataFiles/british_stats_with_positions.csv')
british_bio_df = pd.read_csv('/Users/allendcosta/NBA-NEAT/NEAT-Scouting-Data-Analytics/DataFiles/british_bio_bbl_players.csv')

# Merge the datasets on the "Player" column
merged_df = pd.merge(british_stats_df, british_bio_df, on='Player', how='inner')

# Save the merged DataFrame to a CSV file
merged_df.to_csv('merged_british_bio_stats_data.csv', index=False)

# Display the merged DataFrame
merged_df

# %%
import pandas as pd

# Load the merged DataFrame
merged_df = pd.read_csv('merged_british_bio_stats_data.csv')

# Add a new column named "League" with the value "British Basketball League"
merged_df['League'] = 'British Basketball League'

# Save the DataFrame with the new column to a CSV file
merged_df.to_csv('british_bbl_players_bio_stats.csv', index=False)

# Display the DataFrame
merged_df
# Out:
#       Year Position   #           Player Team_x  GP   MPG   PPG  FGM   FGA  \
# 0     2012       PF   1   Tayo Ogedegebe    SUR  32  32.4  25.3  8.7  16.9
# 1     2012       PF   1   Tayo Ogedegebe    SUR  32  32.4  25.3  8.7  16.9
# 2     2012       PF   1   Tayo Ogedegebe    SUR  32  32.4  25.3  8.7  16.9
# 3     2012       PF   1   Tayo Ogedegebe    SUR  32  32.4  25.3  8.7  16.9
# 4     2012       PF   1   Tayo Ogedegebe    SUR  32  32.4  25.3  8.7  16.9
# ...    ...      ...  ..              ...    ...  ..   ...   ...  ...   ...
# 2119  2023        C  17  Legend Robertin    MAN  31  13.0  17.2  6.6  12.2
# 2120  2023        C  17  Legend Robertin    MAN  31  13.0  17.2  6.6  12.2
# 2121  2023        C  17  Legend Robertin    MAN  31  13.0  17.2  6.6  12.2
# 2122  2023        C  17  Legend Robertin    MAN  31  13.0  17.2  6.6  12.2
# 2123  2023        C  17  Legend Robertin    MAN  31  13.0  17.2  6.6  12.2
#
#       ...   PF  Pos   HT   WT             Team_y  Birth City  \
# ...

# %%
merged_british_df = merged_df

# %%
merged_british_df.nunique()
# Out:
# Year             12
# Position          5
# #                28
# Player           63
# Team_x           12
# GP               30
# MPG             131
# PPG             116
# FGM              81
# FGA              99
# FG%             130
# 3PM              44
# 3PA              82
# 3P%             109
# FTM              57
# FTA              72
# FT%             142
# ORB              55
# DRB              79
# RPG              96
# APG              71
# SPG              32
# BPG              27
# TOV              44
# PF               54
# Pos               9
# HT               15
# WT               31
# Team_y           10
# Birth City       50
# Draft Status     18
# Nationality      13
# Season           12
# League            1
# dtype: int64

# %%
# Get the count of unique players
unique_player_count = merged_british_df['Player'].nunique()

print("Unique Player Count:", unique_player_count)
# Out:
# Unique Player Count: 63
