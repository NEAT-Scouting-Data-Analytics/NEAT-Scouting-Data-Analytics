# %%
import pandas as pd

# %%
#Import dataframe
df_stats = pd.read_csv('/Users/pandit1781/NEAT-Scouting-Data-Analytics/Lithuania/lkl_stats.csv', low_memory=False)
df_bio = pd.read_csv('/Users/pandit1781/NEAT-Scouting-Data-Analytics/Lithuania/lkl_playerbio.csv', low_memory=False)

# %%
merged_df = pd.merge(df_stats, df_bio, on=['Player'], how='inner')

# %%
merged_df.shape
# Out:
# (730, 34)

# %%
# Players to whom more than 4 rows are assigned
merged_df[merged_df.groupby('Player').transform('size')>5]
# Out:
#      Year_x Position   #               Player Team_x  GP     MPG     PPG  \
# 7      2019        G   5        Ignas Vaitkus    SIA  30  33.000  27.750
# 8      2020        G  14        Ignas Vaitkus    JUV  20  27.875  20.375
# 9      2021        F   6        Ignas Vaitkus    JUV  34  33.500  27.250
# 10     2022        F  13        Ignas Vaitkus    JUV  28  29.000  21.375
# 11     2023        F  26        Ignas Vaitkus    PZV  30  37.125  18.625
# ..      ...      ...  ..                  ...    ...  ..     ...     ...
# 285    2021        F  22  Vytenis Lipkevicius    TEC  43  32.375  19.000
# 286    2022        G   7  Vytenis Lipkevicius    TEC   1  25.000  27.000
# 287    2022        G  21  Vytenis Lipkevicius    TEC  37  34.375  18.000
# 288    2023        F  28  Vytenis Lipkevicius    TEC  42  34.250  18.375
# 289    2024        G  25  Vytenis Lipkevicius    TEC  23  32.875  17.375
#
#        FGM     FGA  ...     PF          League  Year_y  Pos   HT   WT  \
# 7    9.875  23.375  ...  4.500  Lithuanian LKL    2019    F  6-2  145
# 8    6.875  17.875  ...  5.875  Lithuanian LKL    2019    F  6-2  145
# 9    9.625  19.875  ...  4.375  Lithuanian LKL    2019    F  6-2  145
# 10   7.375  16.500  ...  4.500  Lithuanian LKL    2019    F  6-2  145
# 11   6.625  14.375  ...  3.875  Lithuanian LKL    2019    F  6-2  145
# ..     ...     ...  ...    ...             ...     ...  ...  ...  ...
# 285  5.625  12.500  ...  5.125  Lithuanian LKL    2019    G  6-6  215
# 286  9.000  15.000  ...  0.000  Lithuanian LKL    2019    G  6-6  215
# 287  5.750  12.750  ...  3.875  Lithuanian LKL    2019    G  6-6  215
# 288  5.875  12.375  ...  4.500  Lithuanian LKL    2019    G  6-6  215
# 289  5.125  11.625  ...  5.500  Lithuanian LKL    2019    G  6-6  215
#
#           Team_y  Birth City               Draft Status  Nationality
# 7       Juventus    Siauliai  2015 NBA Draft, Undrafted    Lithuania
# 8       Juventus    Siauliai  2015 NBA Draft, Undrafted    Lithuania
# 9       Juventus    Siauliai  2015 NBA Draft, Undrafted    Lithuania
# 10      Juventus    Siauliai  2015 NBA Draft, Undrafted    Lithuania
# 11      Juventus    Siauliai  2015 NBA Draft, Undrafted    Lithuania
# ..           ...         ...                        ...          ...
# 285  Lietkabelis     Vilkija  2011 NBA Draft, Undrafted    Lithuania
# 286  Lietkabelis     Vilkija  2011 NBA Draft, Undrafted    Lithuania
# 287  Lietkabelis     Vilkija  2011 NBA Draft, Undrafted    Lithuania
# 288  Lietkabelis     Vilkija  2011 NBA Draft, Undrafted    Lithuania
# 289  Lietkabelis     Vilkija  2011 NBA Draft, Undrafted    Lithuania
#
# [67 rows x 34 columns]

# %%
# Export to CSV
merged_df.to_csv('lithuanian_league.csv', index=False)
