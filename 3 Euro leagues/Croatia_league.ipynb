# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
years = list(range(2019, 2025))
url_start = 'https://basketball.realgm.com/international/league/14/Croatian-A-1-Liga/stats/{year}/Per_48/Qualified/All/points/{position}/desc/1/Regular_Season'
data = []  # List to store parsed data
for year in years:
    for position in ['PG', 'SG', 'SF', 'PF', 'C']:
        url = url_start.format(year=year, position=position)  # Correctly format the URL
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        for row in soup.select('.tablesaw tbody tr'):
            player = [year, position]  # Add the year and position to the player data
            player += [cell.text.strip() for cell in row.find_all('td')]
            data.append(player)
# Creating DataFrame from the collected data
columns = ['Year', 'Position', '#', 'Player', 'Team', 'GP', 'MPG', 'PPG', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
           'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'RPG', 'APG', 'SPG', 'BPG', 'TOV', 'PF']
df = pd.DataFrame(data, columns=columns)
# Save DataFrame to a CSV file
df.to_csv('croatian_stats_with_positions.csv', index=False)
# Display DataFrame
df 
# croatian_stats_with_position = df
# Out:
#      Year Position   #             Player  Team  GP   MPG   PPG   FGM   FGA  \
# 0    2019       PG   1   Martin Junakovic   SIB  11  31.9  29.7  10.3  23.9
# 1    2019       PG   2  Kresimir Radovcic   ZAB  23  27.4  27.5   9.8  21.9
# 2    2019       PG   3     Brian Williams  SRKL  19  25.3  26.6  10.6  20.7
# 3    2019       PG   4       Justin Cobbs   CED  12  22.3  26.0   8.1  19.0
# 4    2019       PG   5       Mario Ihring   VRI  23  32.4  24.8   7.7  16.9
# ..    ...      ...  ..                ...   ...  ..   ...   ...   ...   ...
# 818  2024        C  20     Josip Pavkovic   CIB  19  12.5  15.6   6.5  12.3
# 819  2024        C  21     Matej Perkovic   SIB  28  22.9  13.9   4.9  10.6
# 820  2024        C  22      Ivan Vodopija   DUB  30  21.0  10.0   3.8   8.7
# 821  2024        C  23       Myles Howard   SIB  22  19.6   8.2   2.7   7.6
# 822  2024        C  24         Ante Cosic   BOS  14   3.2   6.5   3.2   7.6
#
#       FG%  3PM  3PA   3P%  FTM  FTA   FT%  ORB  DRB   RPG   APG  SPG  BPG  \
# 0    .429  1.9  7.2  .264  7.2  8.6  .841  0.7  4.5   5.2   9.4  3.4  0.1
# 1    .448  2.6  7.5  .343  5.2  6.2  .852  1.1  4.6   5.6   6.6  2.1  0.0
# 2    .512  1.4  4.4  .318  4.0  5.4  .741  2.5  4.0   6.5   4.8  2.9  0.2
# 3    .425  1.8  4.8  .370  8.1  8.8  .918  1.1  3.1   4.1   9.2  1.3  0.0
# 4    .454  2.3  6.7  .337  7.2  8.6  .842  0.8  6.4   7.3  10.0  2.1  0.3
# ..    ...  ...  ...   ...  ...  ...   ...  ...  ...   ...   ...  ...  ...
# 818  .525  0.0  1.2  .000  2.6  4.0  .650  3.0  9.5  12.5   2.6  1.2  0.6
# 819  .465  0.7  2.5  .265  3.4  4.3  .776  4.6  9.0  13.6   1.1  1.3  1.6
# 820  .439  0.8  2.6  .294  1.6  2.4  .677  2.9  5.5   8.4   3.4  1.1  0.3
# 821  .353  0.0  0.3  .000  2.9  3.8  .765  4.2  8.7  12.9   1.8  2.4  2.4
# 822  .429  0.0  1.1  .000  0.0  0.0  .000  1.1  8.7   9.7   0.0  0.0  3.2
#
#      TOV   PF
# 0    5.5  3.8
# 1    4.0  4.0
# 2    3.1  4.6
# 3    4.1  4.5
# 4    6.4  3.7
# ..   ...  ...
# 818  3.2  8.9
# 819  2.9  6.3
# 820  2.0  3.1
# 821  1.6  5.0
# 822  3.2  7.6
#
# [823 rows x 25 columns]

# %%
croatian_stats_with_position = df

# %%
croatian_stats_with_position['Position'] = croatian_stats_with_position['Position'].replace(['PG', 'SG'], 'G')
croatian_stats_with_position['Position'] = croatian_stats_with_position['Position'].replace(['SF', 'PF'], 'F')

# %%
# Scrape Player Bio in German BBL

import requests
from bs4 import BeautifulSoup
import pandas as pd

pd.set_option('display.max_columns', None)  # so we can see all columns in a wide DataFrame

years = list(range(2019, 2025))

url_start = "https://basketball.realgm.com/international/league/14/Croatian-A-1-Liga/players/{}/{}"

data = []  # List to store parsed data
index = ['658', '762', '863', '952', '1046']
for index, year in zip(index, years):
    url = url_start.format(index, year)  # Properly formatted URL
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    rows = soup.select('.tablesaw tbody tr')
    print(f"Year: {year}, Rows: {len(rows)}")  # Debugging print

    for row in rows:
        player = [year]  # Add the year and position to the player data
        player += [cell.text.strip() for cell in row.find_all('td')]
        data.append(player)

# Extracting column names from the first row of the table
columns = ['Year'] + [header.text.strip() for header in soup.select('.tablesaw thead th')]

# Creating DataFrame from the collected data
df = pd.DataFrame(data, columns=columns)


# Displaying just the first few rows for clarity
df
# Out:
# Year: 2019, Rows: 228
# Year: 2020, Rows: 207
# Year: 2021, Rows: 215
# Year: 2022, Rows: 238
# Year: 2023, Rows: 215
#       Year           Player Pos   HT   WT                       Team  \
# 0     2019  Abdul-Malik Abu   F  6-8  240    KK Vrijednosnice Osijek
# 1     2019    Pablo Aguilar  PF  6-8  235                   Cedevita
# 2     2019  Andro Anzulovic  SG  6-4  200                   KK Zabok
# 3     2019   Roko Anzulovic   G  6-5    -           KK Velika Gorica
# 4     2019      Petar Babic  SG  6-2  196            KK Bosco Zagreb
# ...    ...              ...  ..  ...  ...                        ...
# 1098  2023  Jurica Zagorsak   G  6-6    -                   KK Zadar
# 1099  2023       Vice Zanki   G  6-7    -  KK Cedevita Junior Zagreb
# 1100  2023      Marko Zebic   F  6-4    -          KK Ribola Kastela
# 1101  2023     Karlo Zganec   F  6-9  225                   KK Zadar
# 1102  2023    Ivo Zukanovic   G  6-3    -                   KK Alkar
#
#        Birth City               Draft Status           Nationality
# 0     Boston (MA)  2018 NBA Draft, Undrafted  United StatesNigeria
# 1         Granada  2011 NBA Draft, Undrafted                 Spain
# 2          Zagreb  2013 NBA Draft, Undrafted               Croatia
# 3             N/A  2018 NBA Draft, Undrafted               Croatia
# 4          Zagreb  2007 NBA Draft, Undrafted               Croatia
# ...           ...                        ...                   ...
# 1098          N/A    2027 NBA Draft Eligible               Croatia
# 1099       Zagreb    2027 NBA Draft Eligible               Croatia
# 1100          N/A    2026 NBA Draft Eligible               Croatia
# 1101       Zagreb  2017 NBA Draft, Undrafted               Croatia
# 1102          N/A    2024 NBA Draft Eligible               Croatia
#
# [1103 rows x 9 columns]

# %%
croatian_bio_players = df

# %%
croatian_bio_players  = croatian_bio_players .drop_duplicates(subset=['Player'])

# %%
croatian_bio_players
# Out:
#       Year           Player Pos   HT   WT                     Team  \
# 0     2019  Abdul-Malik Abu   F  6-8  240  KK Vrijednosnice Osijek
# 1     2019    Pablo Aguilar  PF  6-8  235                 Cedevita
# 2     2019  Andro Anzulovic  SG  6-4  200                 KK Zabok
# 3     2019   Roko Anzulovic   G  6-5    -         KK Velika Gorica
# 4     2019      Petar Babic  SG  6-2  196          KK Bosco Zagreb
# ...    ...              ...  ..  ...  ...                      ...
# 1088  2023    Josip Vidovic   F    -    -        KK Ribola Kastela
# 1089  2023    Karlo Vidovic   -    -    -        KK Ribola Kastela
# 1091  2023   Blaz Vojedilov   G  5-6    -                 KK Alkar
# 1098  2023  Jurica Zagorsak   G  6-6    -                 KK Zadar
# 1100  2023      Marko Zebic   F  6-4    -        KK Ribola Kastela
#
#        Birth City               Draft Status           Nationality
# 0     Boston (MA)  2018 NBA Draft, Undrafted  United StatesNigeria
# 1         Granada  2011 NBA Draft, Undrafted                 Spain
# 2          Zagreb  2013 NBA Draft, Undrafted               Croatia
# 3             N/A  2018 NBA Draft, Undrafted               Croatia
# 4          Zagreb  2007 NBA Draft, Undrafted               Croatia
# ...           ...                        ...                   ...
# 1088          N/A  2022 NBA Draft, Undrafted               Croatia
# 1089          N/A    2028 NBA Draft Eligible               Croatia
# 1091          N/A    2025 NBA Draft Eligible               Croatia
# 1098          N/A    2027 NBA Draft Eligible               Croatia
# 1100          N/A    2026 NBA Draft Eligible               Croatia
#
# [590 rows x 9 columns]

# %%
# Assuming british_merged_df is your DataFrame
croatian_bio_players.to_csv('croatian_bio_players.csv', index=False)

# %%
croatian_bio_players['Pos'] = croatian_bio_players['Pos'].replace(['PG', 'SG'], 'G')
croatian_bio_players['Pos'] = croatian_bio_players['Pos'].replace(['SF', 'PF'], 'F')
# Out:
# /var/folders/7h/233xrn2x20n5883dfdqwt5zr0000gn/T/ipykernel_5059/1306295011.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   croatian_bio_players['Pos'] = croatian_bio_players['Pos'].replace(['PG', 'SG'], 'G')
# /var/folders/7h/233xrn2x20n5883dfdqwt5zr0000gn/T/ipykernel_5059/1306295011.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   croatian_bio_players['Pos'] = croatian_bio_players['Pos'].replace(['SF', 'PF'], 'F')

# %%
import pandas as pd

# Load the datasets
croatian_stats_with_position = pd.read_csv('/Users/allendcosta/NBA-NEAT/NEAT-Scouting-Data-Analytics/3 Euro leagues/croatian_stats_with_positions.csv')
croatian_bio_players = pd.read_csv('/Users/allendcosta/NBA-NEAT/NEAT-Scouting-Data-Analytics/3 Euro leagues/croatian_bio_players.csv')

# Merge the datasets on the "Player" column
merged_df = pd.merge(croatian_bio_players, croatian_stats_with_position, on='Player', how='inner')

# # Save the merged DataFrame to a CSV file
# merged_df.to_csv('merged_greek_bio_stats_data.csv', index=False)

# Display the merged DataFrame
merged_df
merged_croatian_df = merged_df

# %%
# Assuming british_merged_df is your DataFrame
merged_croatian_df['League'] = 'Croatian Basketball League'

# Display DataFrame
merged_croatian_df
# Out:
#      Year_x            Player Pos   HT   WT                   Team_x  \
# 0      2019   Abdul-Malik Abu   F  6-8  240  KK Vrijednosnice Osijek
# 1      2019   Andro Anzulovic  SG  6-4  200                 KK Zabok
# 2      2019   Andro Anzulovic  SG  6-4  200                 KK Zabok
# 3      2019   Andro Anzulovic  SG  6-4  200                 KK Zabok
# 4      2019   Andro Anzulovic  SG  6-4  200                 KK Zabok
# ..      ...               ...  ..  ...  ...                      ...
# 774    2023  Derryck Thornton  PG  6-3  195              KK Skrljevo
# 775    2023       Boris Tisma  SF  6-9  207                 KK Split
# 776    2023       Boris Tisma  SF  6-9  207                 KK Split
# 777    2023     Josip Vidovic   F    -    -        KK Ribola Kastela
# 778    2023    Blaz Vojedilov   G  5-6    -                 KK Alkar
#
#          Birth City               Draft Status           Nationality  Year_y  \
# 0       Boston (MA)  2018 NBA Draft, Undrafted  United StatesNigeria    2019
# 1            Zagreb  2013 NBA Draft, Undrafted               Croatia    2019
# 2            Zagreb  2013 NBA Draft, Undrafted               Croatia    2020
# 3            Zagreb  2013 NBA Draft, Undrafted               Croatia    2021
# 4            Zagreb  2013 NBA Draft, Undrafted               Croatia    2023
# ..              ...                        ...                   ...     ...
# 774  Las Vegas (NV)  2020 NBA Draft, Undrafted         United States    2023
# 775          Zagreb    2024 NBA Draft Eligible               Croatia    2023
# 776          Zagreb    2024 NBA Draft Eligible               Croatia    2024
# 777             NaN  2022 NBA Draft, Undrafted               Croatia    2023
# 778             NaN    2025 NBA Draft Eligible               Croatia    2023
#
#     Position   # Team_y  GP   MPG   PPG  FGM   FGA    FG%  3PM  3PA    3P%  \
# 0          C   3    VRI  19  29.0  24.1  9.7  16.5  0.584  0.8  1.7  0.450
# 1         SG  16    ZAB  24  21.0   9.6  3.0   8.9  0.344  1.5  6.2  0.246
# 2         SG  21    ZAB  18  23.0  13.1  3.8   9.7  0.393  2.5  7.1  0.361
# 3         SG  25    ZAB  31  22.8  13.2  3.7   9.4  0.396  2.8  7.3  0.383
# 4         SG  27    DIN  34  22.2  12.0  3.9   8.8  0.449  2.9  7.3  0.391
# ..       ...  ..    ...  ..   ...   ...  ...   ...    ...  ...  ...    ...
# 774       PG   2   SRKL  14  31.7  31.3  9.4  23.2  0.407  1.8  6.4  0.288
# 775       SF   9    SPL  26  18.0  20.4  7.2  17.6  0.407  3.6  9.5  0.376
# 776       SF  16    SPL  29  21.9  17.2  6.0  13.8  0.437  2.9  7.6  0.386
# 777       SF  33    RIB   2  22.0   9.8  2.2   8.7  0.250  1.1  6.5  0.167
# 778       PG  31    ALK  20   3.2  14.4  2.3   8.3  0.273  0.0  0.0  0.000
#
#       FTM   FTA    FT%  ORB  DRB   RPG   APG  SPG  BPG   TOV    PF  \
# 0     4.0   7.0  0.575  5.6  9.4  15.0   2.4  0.9  1.3   2.8   3.1
# 1     2.0   2.4  0.840  0.8  3.1   3.9   5.6  3.9  0.3   1.8   3.6
# 2     2.9   3.7  0.781  0.7  4.1   4.7   7.1  2.8  0.2   1.7   3.5
# 3     3.0   3.5  0.846  0.8  3.8   4.6   4.7  2.2  0.3   1.8   3.9
# 4     1.2   1.5  0.792  0.7  3.8   4.5   5.0  2.4  0.0   1.5   5.3
# ..    ...   ...    ...  ...  ...   ...   ...  ...  ...   ...   ...
# 774  10.6  12.2  0.867  1.3  4.7   6.0  10.8  2.3  0.1   5.1   3.0
# 775   2.5   4.3  0.571  2.9  6.5   9.3   2.9  2.5  1.1   2.5   5.7
# 776   2.2   3.7  0.592  1.8  7.3   9.1   3.7  1.7  0.5   3.1   5.3
# 777   4.4   5.4  0.800  1.1  5.4   6.5   7.6  3.3  0.0   5.4   6.5
# 778   9.8  12.9  0.765  0.8  3.8   4.5   8.3  0.8  0.0  12.1  10.6
#
#                          League
# 0    Croatian Basketball League
# 1    Croatian Basketball League
# 2    Croatian Basketball League
# 3    Croatian Basketball League
# 4    Croatian Basketball League
# ..                          ...
# 774  Croatian Basketball League
# 775  Croatian Basketball League
# 776  Croatian Basketball League
# 777  Croatian Basketball League
# 778  Croatian Basketball League
#
# [779 rows x 34 columns]

# %%
# Save the merged DataFrame to a CSV file
merged_df.to_csv('merged_croatian_bio_stats_data.csv', index=False)
