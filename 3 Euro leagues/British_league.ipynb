# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
years = list(range(2019, 2025))
url_start = 'https://basketball.realgm.com/international/league/69/British-BBL/stats/{year}/Per_48/Qualified/All/points/{position}/desc/1/Regular_Season'
data = []  # List to store parsed data
for year in years:
    for position in ['PG', 'SG', 'SF', 'PF', 'C']:
        url = url_start.format(year=year, position=position)  # Correctly format the URL
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        for row in soup.select('.tablesaw tbody tr'):
            player = [year, position]  # Add the year and position to the player data
            player += [cell.text.strip() for cell in row.find_all('td')]
            data.append(player)
# Creating DataFrame from the collected data
columns = ['Year', 'Position', '#', 'Player', 'Team', 'GP', 'MPG', 'PPG', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
           'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'RPG', 'APG', 'SPG', 'BPG', 'TOV', 'PF']
df = pd.DataFrame(data, columns=columns)
# Save DataFrame to a CSV file
df.to_csv('british_stats_with_positions.csv', index=False)
# Display DataFrame
df 
british_stats_with_positions = df

# %%
british_stats_with_positions
# Out:
#       Year Position   #              Player Team  GP   MPG   PPG   FGM   FGA  \
# 0     2012       PG   1     Cameron Rundles  LEI  35  33.7  27.7  10.5  23.2
# 1     2012       PG   2          Paul Gause  NEW  32  25.2  26.7   9.8  21.3
# 2     2012       PG   3         Jeremy Bell  UCP  32  36.6  25.3   9.2  21.9
# 3     2012       PG   4     Jimmy Langhurst  OHS  27  35.5  24.9   8.3  17.6
# 4     2012       PG   5          Adam Brown  CHE  33  38.5  24.6   9.7  21.9
# ...    ...      ...  ..                 ...  ...  ..   ...   ...   ...   ...
# 1018  2023        C  18     Donovan Johnson  NEW  14  21.0  16.5   5.1  13.9
# 1019  2023        C  19       Hasahn French  NEW  25  25.1  13.9   6.5  13.5
# 1020  2023        C  20  Michael Ochereobia  CHE  24  18.3  12.6   5.8  10.2
# 1021  2023        C  21    Jonathan Komagum  LON  24  14.0  10.5   3.6   9.0
# 1022  2023        C  22        Samuel Keita  PLY  34   7.2   9.8   3.3   8.2
#
#       ...  FTA   FT%  ORB   DRB   RPG  APG  SPG  BPG  TOV    PF
# 0     ...  6.1  .584  1.3   3.9   5.1  6.2  1.4  0.0  3.5   2.4
# 1     ...  7.0  .678  2.4   6.4   8.9  6.2  3.3  0.5  4.3   5.6
# 2     ...  7.6  .769  1.2   4.8   6.1  3.9  2.1  0.0  3.4   3.2
# 3     ...  5.6  .920  1.3   4.1   5.4  3.8  1.2  0.0  3.1   2.1
# 4     ...  4.1  .826  1.4   4.2   5.6  6.3  2.6  0.1  5.1   3.7
# ...   ...  ...   ...  ...   ...   ...  ...  ...  ...  ...   ...
# 1018  ...  4.9  .900  2.3   8.2  10.4  1.8  1.5  0.8  3.3   7.7
# 1019  ...  2.1  .286  6.0  11.4  17.5  5.9  2.3  2.8  3.1   6.4
# 1020  ...  1.9  .529  4.8   7.7  12.5  1.8  1.1  1.5  4.2   5.7
# 1021  ...  2.9  .700  5.3   8.6  13.9  1.9  1.1  1.3  1.7   4.6
# 1022  ...  8.1  .390  5.3   7.3  12.6  2.4  1.6  0.2  3.5  11.8
#
# [1023 rows x 25 columns]

# %%
# british_stats_with_positions = british_stats_with_positions.drop_duplicates(subset=['Player'])

# %%
british_stats_with_positions['Position'] = british_stats_with_positions['Position'].replace(['PG', 'SG'], 'G')
british_stats_with_positions['Position'] = british_stats_with_positions['Position'].replace(['SF', 'PF'], 'F')

# %%
british_stats_with_positions
# Out:
#      Year Position   #              Player Team  GP   MPG   PPG  FGM   FGA  \
# 0    2019        G   1       Jalan McCloud  BRI  27  27.9  26.3  9.6  21.9
# 1    2019        G   2       Quincy Taylor  SUR  33  34.9  24.7  9.4  20.1
# 2    2019        G   3     Rahmon Fletcher  NEW  34  34.2  23.8  9.0  19.1
# 3    2019        G   4        Josh Wilcher  UCP  35  35.6  22.8  7.2  15.7
# 4    2019        G   5       Jordan Whelan  WOR  33  21.1  22.1  8.2  19.9
# ..    ...      ...  ..                 ...  ...  ..   ...   ...  ...   ...
# 520  2023        C  18     Donovan Johnson  NEW  14  21.0  16.5  5.1  13.9
# 521  2023        C  19       Hasahn French  NEW  25  25.1  13.9  6.5  13.5
# 522  2023        C  20  Michael Ochereobia  CHE  24  18.3  12.6  5.8  10.2
# 523  2023        C  21    Jonathan Komagum  LON  24  14.0  10.5  3.6   9.0
# 524  2023        C  22        Samuel Keita  PLY  34   7.2   9.8  3.3   8.2
#
#      ...  FTA   FT%  ORB   DRB   RPG   APG  SPG  BPG  TOV    PF
# 0    ...  6.1  .833  1.9   2.8   4.7   6.8  3.6  0.3  3.8   4.2
# 1    ...  5.9  .796  1.4   4.4   5.8   8.1  2.0  0.2  3.1   2.2
# 2    ...  4.4  .785  0.6   3.4   4.0  12.4  2.2  0.0  4.2   2.7
# 3    ...  5.9  .838  1.1   3.2   4.3   7.7  1.5  0.0  2.7   1.7
# 4    ...  4.1  .746  1.4   4.7   6.1   2.4  1.9  0.3  2.6   4.9
# ..   ...  ...   ...  ...   ...   ...   ...  ...  ...  ...   ...
# 520  ...  4.9  .900  2.3   8.2  10.4   1.8  1.5  0.8  3.3   7.7
# 521  ...  2.1  .286  6.0  11.4  17.5   5.9  2.3  2.8  3.1   6.4
# 522  ...  1.9  .529  4.8   7.7  12.5   1.8  1.1  1.5  4.2   5.7
# 523  ...  2.9  .700  5.3   8.6  13.9   1.9  1.1  1.3  1.7   4.6
# 524  ...  8.1  .390  5.3   7.3  12.6   2.4  1.6  0.2  3.5  11.8
#
# [525 rows x 25 columns]

# %%
# Scrape Player Bio in German BBL

import requests
from bs4 import BeautifulSoup
import pandas as pd

pd.set_option('display.max_columns', None)  # so we can see all columns in a wide DataFrame

years = list(range(2019, 2025))

url_start = "https://basketball.realgm.com/international/league/69/British-BBL/players/{}/{}"

data = []  # List to store parsed data
index = ['702', '803', '904', '993', '1085']
for index, year in zip(index, years):
    url = url_start.format(index, year)  # Properly formatted URL
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    rows = soup.select('.tablesaw tbody tr')
    print(f"Year: {year}, Rows: {len(rows)}")  # Debugging print

    for row in rows:
        player = [year]  # Add the year and position to the player data
        player += [cell.text.strip() for cell in row.find_all('td')]
        data.append(player)

# Extracting column names from the first row of the table
columns = ['Year'] + [header.text.strip() for header in soup.select('.tablesaw thead th')]

# Creating DataFrame from the collected data
df = pd.DataFrame(data, columns=columns)
# Save DataFrame to a CSV file
df.to_csv('british_bio.csv', index=False)
# Displaying just the first few rows for clarity
df
# Out:
# Year: 2019, Rows: 182
# Year: 2020, Rows: 164
# Year: 2021, Rows: 172
# Year: 2022, Rows: 161
# Year: 2023, Rows: 160
#      Year                Player Pos    HT   WT                         Team  \
# 0    2019         Kieron Achara  FC   6-8  240         Caledonia Gladiators
# 1    2019         Jawad Adekoya  GF   6-6  190  Plymouth University Raiders
# 2    2019            Mo Adepoju   F   6-5    -             Worcester Wolves
# 3    2019       Chris Alexander  PG   6-1  185             Sheffield Sharks
# 4    2019  Dii'Jon Allen-Jordan   F   6-5  190             Cheshire Phoenix
# ..    ...                   ...  ..   ...  ...                          ...
# 834  2023            Will White   F   6-3    -       Plymouth City Patriots
# 835  2023      Antonio Williams   G   6-0  185       Plymouth City Patriots
# 836  2023         Dirk Williams  SG   6-5  180            Manchester Giants
# 837  2023         Benjamin Woog   C   6-7  227             Leicester Riders
# 838  2023       Tomislav Zubcic   C  6-10  230                 London Lions
#
#            Birth City               Draft Status      Nationality
# 0            Stirling  2008 NBA Draft, Undrafted  ScotlandEngland
# 1    Tinley Park (IL)  2016 NBA Draft, Undrafted    United States
# 2                 N/A  2019 NBA Draft, Undrafted          Nigeria
# 3         Lawton (OK)  2006 NBA Draft, Undrafted    United States
# 4     Plainfield (NJ)  2016 NBA Draft, Undrafted    United States
# ..                ...                        ...              ...
# 834               N/A    2024 NBA Draft Eligible          England
# 835      Chicago (IL)  2020 NBA Draft, Undrafted    United States
# 836     Homewood (AL)  2017 NBA Draft, Undrafted    United States
# 837     Haverfordwest    2025 NBA Draft Eligible            Wales
# 838             Zadar         2012 Rnd 2 Pick 26          Croatia
#
# [839 rows x 9 columns]

# %%
british_bio_bbl_players = df

# %%
british_bio_bbl_players = british_bio_bbl_players.drop_duplicates(subset=['Player'])

# %%
british_bio_bbl_players
# Out:
#      Year                Player Pos    HT   WT                         Team  \
# 0    2019         Kieron Achara  FC   6-8  240         Caledonia Gladiators
# 1    2019         Jawad Adekoya  GF   6-6  190  Plymouth University Raiders
# 2    2019            Mo Adepoju   F   6-5    -             Worcester Wolves
# 3    2019       Chris Alexander  PG   6-1  185             Sheffield Sharks
# 4    2019  Dii'Jon Allen-Jordan   F   6-5  190             Cheshire Phoenix
# ..    ...                   ...  ..   ...  ...                          ...
# 824  2023         Lesley Varner   F   6-7  185             Newcastle Eagles
# 827  2023           Padiet Wang   G   6-4  165             Surrey Scorchers
# 831  2023   Jelani Watson-Gayle  PG   6-1  185               Bristol Flyers
# 834  2023            Will White   F   6-3    -       Plymouth City Patriots
# 838  2023       Tomislav Zubcic   C  6-10  230                 London Lions
#
#            Birth City               Draft Status               Nationality
# 0            Stirling  2008 NBA Draft, Undrafted           ScotlandEngland
# 1    Tinley Park (IL)  2016 NBA Draft, Undrafted             United States
# 2                 N/A  2019 NBA Draft, Undrafted                   Nigeria
# 3         Lawton (OK)  2006 NBA Draft, Undrafted             United States
# 4     Plainfield (NJ)  2016 NBA Draft, Undrafted             United States
# ..                ...                        ...                       ...
# 824       Dallas (TX)  2020 NBA Draft, Undrafted             United States
# 827       Aurora (CO)  2020 NBA Draft, Undrafted  United StatesSouth Sudan
# 831            London  2023 NBA Draft, Undrafted                   England
# 834               N/A    2024 NBA Draft Eligible                   England
# 838             Zadar         2012 Rnd 2 Pick 26                   Croatia
#
# [524 rows x 9 columns]

# %%
british_bio_bbl_players['Pos'] = british_bio_bbl_players['Pos'].replace(['PG', 'SG'], 'G')
british_bio_bbl_players['Pos'] = british_bio_bbl_players['Pos'].replace(['SF', 'PF'], 'F')
# Out:
# /var/folders/7h/233xrn2x20n5883dfdqwt5zr0000gn/T/ipykernel_5035/4062504979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   british_bio_bbl_players['Pos'] = british_bio_bbl_players['Pos'].replace(['PG', 'SG'], 'G')
# /var/folders/7h/233xrn2x20n5883dfdqwt5zr0000gn/T/ipykernel_5035/4062504979.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   british_bio_bbl_players['Pos'] = british_bio_bbl_players['Pos'].replace(['SF', 'PF'], 'F')

# %%
british_stats_with_positions
# Out:
#      Year Position   #              Player Team  GP   MPG   PPG  FGM   FGA  \
# 0    2019        G   1       Jalan McCloud  BRI  27  27.9  26.3  9.6  21.9
# 1    2019        G   2       Quincy Taylor  SUR  33  34.9  24.7  9.4  20.1
# 2    2019        G   3     Rahmon Fletcher  NEW  34  34.2  23.8  9.0  19.1
# 3    2019        G   4        Josh Wilcher  UCP  35  35.6  22.8  7.2  15.7
# 4    2019        G   5       Jordan Whelan  WOR  33  21.1  22.1  8.2  19.9
# ..    ...      ...  ..                 ...  ...  ..   ...   ...  ...   ...
# 520  2023        C  18     Donovan Johnson  NEW  14  21.0  16.5  5.1  13.9
# 521  2023        C  19       Hasahn French  NEW  25  25.1  13.9  6.5  13.5
# 522  2023        C  20  Michael Ochereobia  CHE  24  18.3  12.6  5.8  10.2
# 523  2023        C  21    Jonathan Komagum  LON  24  14.0  10.5  3.6   9.0
# 524  2023        C  22        Samuel Keita  PLY  34   7.2   9.8  3.3   8.2
#
#       FG%  3PM  3PA   3P%  FTM  FTA   FT%  ORB   DRB   RPG   APG  SPG  BPG  \
# 0    .437  2.1  6.4  .330  5.1  6.1  .833  1.9   2.8   4.7   6.8  3.6  0.3
# 1    .467  1.2  4.2  .290  4.7  5.9  .796  1.4   4.4   5.8   8.1  2.0  0.2
# 2    .469  2.4  6.7  .362  3.5  4.4  .785  0.6   3.4   4.0  12.4  2.2  0.0
# 3    .456  3.5  8.8  .395  5.0  5.9  .838  1.1   3.2   4.3   7.7  1.5  0.0
# 4    .412  2.6  9.5  .275  3.0  4.1  .746  1.4   4.7   6.1   2.4  1.9  0.3
# ..    ...  ...  ...   ...  ...  ...   ...  ...   ...   ...   ...  ...  ...
# 520  .365  2.0  7.8  .250  4.4  4.9  .900  2.3   8.2  10.4   1.8  1.5  0.8
# 521  .483  0.3  1.6  .190  0.6  2.1  .286  6.0  11.4  17.5   5.9  2.3  2.8
# 522  .570  0.0  0.0  .000  1.0  1.9  .529  4.8   7.7  12.5   1.8  1.1  1.5
# 523  .397  1.3  3.0  .429  2.0  2.9  .700  5.3   8.6  13.9   1.9  1.1  1.3
# 524  .405  0.0  0.0  .000  3.1  8.1  .390  5.3   7.3  12.6   2.4  1.6  0.2
#
#      TOV    PF
# 0    3.8   4.2
# 1    3.1   2.2
# 2    4.2   2.7
# 3    2.7   1.7
# 4    2.6   4.9
# ..   ...   ...
# 520  3.3   7.7
# 521  3.1   6.4
# 522  4.2   5.7
# 523  1.7   4.6
# 524  3.5  11.8
#
# [525 rows x 25 columns]

# %%
import pandas as pd

# Load the datasets
british_stats_df = pd.read_csv('/Users/allendcosta/NBA-NEAT/NEAT-Scouting-Data-Analytics/3 Euro leagues/british_stats_with_positions.csv')
british_bio_df = pd.read_csv('/Users/allendcosta/NBA-NEAT/NEAT-Scouting-Data-Analytics/3 Euro leagues/british_bio.csv')

# Merge the datasets on the "Player" column
merged_df = pd.merge(british_stats_with_positions , british_bio_bbl_players, on='Player', how='inner')

# Save the merged DataFrame to a CSV file
merged_df.to_csv('merged_british_bio_stats_data.csv', index=False)

# Display the merged DataFrame
merged_df
# Out:
#      Year_x Position   #            Player Team_x  GP   MPG   PPG  FGM   FGA  \
# 0      2019        G   1     Jalan McCloud    BRI  27  27.9  26.3  9.6  21.9
# 1      2019        G   2     Quincy Taylor    SUR  33  34.9  24.7  9.4  20.1
# 2      2023        G  15     Quincy Taylor    SUR  15  34.0  17.2  7.5  16.9
# 3      2019        G   3   Rahmon Fletcher    NEW  34  34.2  23.8  9.0  19.1
# 4      2020        G   3   Rahmon Fletcher    NEW  13  33.5  23.1  9.1  19.3
# ..      ...      ...  ..               ...    ...  ..   ...   ...  ...   ...
# 518    2023        C  16     Aaron Menzies    LEI  27  13.2  17.4  7.0  11.6
# 519    2023        C  17   Legend Robertin    MAN  31  13.0  17.2  6.6  12.2
# 520    2023        C  19     Hasahn French    NEW  25  25.1  13.9  6.5  13.5
# 521    2023        C  21  Jonathan Komagum    LON  24  14.0  10.5  3.6   9.0
# 522    2023        C  22      Samuel Keita    PLY  34   7.2   9.8  3.3   8.2
#
#       FG%  3PM  3PA   3P%  FTM  FTA   FT%  ORB   DRB   RPG   APG  SPG  BPG  \
# 0    .437  2.1  6.4  .330  5.1  6.1  .833  1.9   2.8   4.7   6.8  3.6  0.3
# 1    .467  1.2  4.2  .290  4.7  5.9  .796  1.4   4.4   5.8   8.1  2.0  0.2
# 2    .444  1.0  4.4  .234  1.1  2.0  .571  0.8   3.3   4.1   6.7  1.2  0.2
# 3    .469  2.4  6.7  .362  3.5  4.4  .785  0.6   3.4   4.0  12.4  2.2  0.0
# 4    .474  1.1  5.3  .208  3.7  5.2  .723  0.4   3.2   3.6  12.9  1.3  0.1
# ..    ...  ...  ...   ...  ...  ...   ...  ...   ...   ...   ...  ...  ...
# 518  .605  0.0  0.0  .000  3.4  6.5  .521  6.7  11.9  18.6   1.5  0.4  3.0
# 519  .539  0.0  0.0  .000  4.1  7.9  .515  5.6   7.9  13.5   1.2  0.4  3.5
# 520  .483  0.3  1.6  .190  0.6  2.1  .286  6.0  11.4  17.5   5.9  2.3  2.8
# 521  .397  1.3  3.0  .429  2.0  2.9  .700  5.3   8.6  13.9   1.9  1.1  1.3
# 522  .405  0.0  0.0  .000  3.1  8.1  .390  5.3   7.3  12.6   2.4  1.6  0.2
#
#      TOV    PF  Year_y Pos    HT   WT                  Team_y  \
# 0    3.8   4.2    2019   G  5-11  175          Bristol Flyers
# 1    3.1   2.2    2019   G   6-0  180        Surrey Scorchers
# 2    4.2   3.2    2019   G   6-0  180        Surrey Scorchers
# 3    4.2   2.7    2019   G  5-10  165        Newcastle Eagles
# 4    5.5   3.0    2019   G  5-10  165        Newcastle Eagles
# ..   ...   ...     ...  ..   ...  ...                     ...
# 518  3.9   9.4    2023   C   7-3  265        Leicester Riders
# 519  2.6   8.0    2022   C   7-1  280        Surrey Scorchers
# 520  3.1   6.4    2023   F   6-7  240        Newcastle Eagles
# 521  1.7   4.6    2023   C   6-9  215            London Lions
# 522  3.5  11.8    2023   C  6-10  216  Plymouth City Patriots
#
#            Birth City               Draft Status    Nationality
# 0     Fort Worth (TX)  2018 NBA Draft, Undrafted  United States
# 1        Wichita (KS)  2015 NBA Draft, Undrafted  United States
# 2        Wichita (KS)  2015 NBA Draft, Undrafted  United States
# 3    Kansas City (MO)  2011 NBA Draft, Undrafted  United States
# 4    Kansas City (MO)  2011 NBA Draft, Undrafted  United States
# ..                ...                        ...            ...
# 518        Manchester  2020 NBA Draft, Undrafted        England
# 519            London  2018 NBA Draft, Undrafted        England
# 520   Middletown (NY)  2021 NBA Draft, Undrafted  United States
# 521            London  2023 NBA Draft, Undrafted        England
# 522            London  2023 NBA Draft, Undrafted        England
#
# [523 rows x 33 columns]

# %%
british_merged_df = merged_df
british_merged_df
# Out:
#      Year_x Position   #            Player Team_x  GP   MPG   PPG  FGM   FGA  \
# 0      2019        G   1     Jalan McCloud    BRI  27  27.9  26.3  9.6  21.9
# 1      2019        G   2     Quincy Taylor    SUR  33  34.9  24.7  9.4  20.1
# 2      2023        G  15     Quincy Taylor    SUR  15  34.0  17.2  7.5  16.9
# 3      2019        G   3   Rahmon Fletcher    NEW  34  34.2  23.8  9.0  19.1
# 4      2020        G   3   Rahmon Fletcher    NEW  13  33.5  23.1  9.1  19.3
# ..      ...      ...  ..               ...    ...  ..   ...   ...  ...   ...
# 518    2023        C  16     Aaron Menzies    LEI  27  13.2  17.4  7.0  11.6
# 519    2023        C  17   Legend Robertin    MAN  31  13.0  17.2  6.6  12.2
# 520    2023        C  19     Hasahn French    NEW  25  25.1  13.9  6.5  13.5
# 521    2023        C  21  Jonathan Komagum    LON  24  14.0  10.5  3.6   9.0
# 522    2023        C  22      Samuel Keita    PLY  34   7.2   9.8  3.3   8.2
#
#       FG%  3PM  3PA   3P%  FTM  FTA   FT%  ORB   DRB   RPG   APG  SPG  BPG  \
# 0    .437  2.1  6.4  .330  5.1  6.1  .833  1.9   2.8   4.7   6.8  3.6  0.3
# 1    .467  1.2  4.2  .290  4.7  5.9  .796  1.4   4.4   5.8   8.1  2.0  0.2
# 2    .444  1.0  4.4  .234  1.1  2.0  .571  0.8   3.3   4.1   6.7  1.2  0.2
# 3    .469  2.4  6.7  .362  3.5  4.4  .785  0.6   3.4   4.0  12.4  2.2  0.0
# 4    .474  1.1  5.3  .208  3.7  5.2  .723  0.4   3.2   3.6  12.9  1.3  0.1
# ..    ...  ...  ...   ...  ...  ...   ...  ...   ...   ...   ...  ...  ...
# 518  .605  0.0  0.0  .000  3.4  6.5  .521  6.7  11.9  18.6   1.5  0.4  3.0
# 519  .539  0.0  0.0  .000  4.1  7.9  .515  5.6   7.9  13.5   1.2  0.4  3.5
# 520  .483  0.3  1.6  .190  0.6  2.1  .286  6.0  11.4  17.5   5.9  2.3  2.8
# 521  .397  1.3  3.0  .429  2.0  2.9  .700  5.3   8.6  13.9   1.9  1.1  1.3
# 522  .405  0.0  0.0  .000  3.1  8.1  .390  5.3   7.3  12.6   2.4  1.6  0.2
#
#      TOV    PF  Year_y Pos    HT   WT                  Team_y  \
# 0    3.8   4.2    2019   G  5-11  175          Bristol Flyers
# 1    3.1   2.2    2019   G   6-0  180        Surrey Scorchers
# 2    4.2   3.2    2019   G   6-0  180        Surrey Scorchers
# 3    4.2   2.7    2019   G  5-10  165        Newcastle Eagles
# 4    5.5   3.0    2019   G  5-10  165        Newcastle Eagles
# ..   ...   ...     ...  ..   ...  ...                     ...
# 518  3.9   9.4    2023   C   7-3  265        Leicester Riders
# 519  2.6   8.0    2022   C   7-1  280        Surrey Scorchers
# 520  3.1   6.4    2023   F   6-7  240        Newcastle Eagles
# 521  1.7   4.6    2023   C   6-9  215            London Lions
# 522  3.5  11.8    2023   C  6-10  216  Plymouth City Patriots
#
#            Birth City               Draft Status    Nationality
# 0     Fort Worth (TX)  2018 NBA Draft, Undrafted  United States
# 1        Wichita (KS)  2015 NBA Draft, Undrafted  United States
# 2        Wichita (KS)  2015 NBA Draft, Undrafted  United States
# 3    Kansas City (MO)  2011 NBA Draft, Undrafted  United States
# 4    Kansas City (MO)  2011 NBA Draft, Undrafted  United States
# ..                ...                        ...            ...
# 518        Manchester  2020 NBA Draft, Undrafted        England
# 519            London  2018 NBA Draft, Undrafted        England
# 520   Middletown (NY)  2021 NBA Draft, Undrafted  United States
# 521            London  2023 NBA Draft, Undrafted        England
# 522            London  2023 NBA Draft, Undrafted        England
#
# [523 rows x 33 columns]

# %%
# Assuming british_merged_df is your DataFrame
british_merged_df['League'] = 'British Basketball League'

# Display DataFrame
british_merged_df
# Out:
#      Year_x Position   #            Player Team_x  GP   MPG   PPG  FGM   FGA  \
# 0      2019        G   1     Jalan McCloud    BRI  27  27.9  26.3  9.6  21.9
# 1      2019        G   2     Quincy Taylor    SUR  33  34.9  24.7  9.4  20.1
# 2      2023        G  15     Quincy Taylor    SUR  15  34.0  17.2  7.5  16.9
# 3      2019        G   3   Rahmon Fletcher    NEW  34  34.2  23.8  9.0  19.1
# 4      2020        G   3   Rahmon Fletcher    NEW  13  33.5  23.1  9.1  19.3
# ..      ...      ...  ..               ...    ...  ..   ...   ...  ...   ...
# 518    2023        C  16     Aaron Menzies    LEI  27  13.2  17.4  7.0  11.6
# 519    2023        C  17   Legend Robertin    MAN  31  13.0  17.2  6.6  12.2
# 520    2023        C  19     Hasahn French    NEW  25  25.1  13.9  6.5  13.5
# 521    2023        C  21  Jonathan Komagum    LON  24  14.0  10.5  3.6   9.0
# 522    2023        C  22      Samuel Keita    PLY  34   7.2   9.8  3.3   8.2
#
#       FG%  3PM  3PA   3P%  FTM  FTA   FT%  ORB   DRB   RPG   APG  SPG  BPG  \
# 0    .437  2.1  6.4  .330  5.1  6.1  .833  1.9   2.8   4.7   6.8  3.6  0.3
# 1    .467  1.2  4.2  .290  4.7  5.9  .796  1.4   4.4   5.8   8.1  2.0  0.2
# 2    .444  1.0  4.4  .234  1.1  2.0  .571  0.8   3.3   4.1   6.7  1.2  0.2
# 3    .469  2.4  6.7  .362  3.5  4.4  .785  0.6   3.4   4.0  12.4  2.2  0.0
# 4    .474  1.1  5.3  .208  3.7  5.2  .723  0.4   3.2   3.6  12.9  1.3  0.1
# ..    ...  ...  ...   ...  ...  ...   ...  ...   ...   ...   ...  ...  ...
# 518  .605  0.0  0.0  .000  3.4  6.5  .521  6.7  11.9  18.6   1.5  0.4  3.0
# 519  .539  0.0  0.0  .000  4.1  7.9  .515  5.6   7.9  13.5   1.2  0.4  3.5
# 520  .483  0.3  1.6  .190  0.6  2.1  .286  6.0  11.4  17.5   5.9  2.3  2.8
# 521  .397  1.3  3.0  .429  2.0  2.9  .700  5.3   8.6  13.9   1.9  1.1  1.3
# 522  .405  0.0  0.0  .000  3.1  8.1  .390  5.3   7.3  12.6   2.4  1.6  0.2
#
#      TOV    PF  Year_y Pos    HT   WT                  Team_y  \
# 0    3.8   4.2    2019   G  5-11  175          Bristol Flyers
# 1    3.1   2.2    2019   G   6-0  180        Surrey Scorchers
# 2    4.2   3.2    2019   G   6-0  180        Surrey Scorchers
# 3    4.2   2.7    2019   G  5-10  165        Newcastle Eagles
# 4    5.5   3.0    2019   G  5-10  165        Newcastle Eagles
# ..   ...   ...     ...  ..   ...  ...                     ...
# 518  3.9   9.4    2023   C   7-3  265        Leicester Riders
# 519  2.6   8.0    2022   C   7-1  280        Surrey Scorchers
# 520  3.1   6.4    2023   F   6-7  240        Newcastle Eagles
# 521  1.7   4.6    2023   C   6-9  215            London Lions
# 522  3.5  11.8    2023   C  6-10  216  Plymouth City Patriots
#
#            Birth City               Draft Status    Nationality  \
# 0     Fort Worth (TX)  2018 NBA Draft, Undrafted  United States
# 1        Wichita (KS)  2015 NBA Draft, Undrafted  United States
# 2        Wichita (KS)  2015 NBA Draft, Undrafted  United States
# 3    Kansas City (MO)  2011 NBA Draft, Undrafted  United States
# 4    Kansas City (MO)  2011 NBA Draft, Undrafted  United States
# ..                ...                        ...            ...
# 518        Manchester  2020 NBA Draft, Undrafted        England
# 519            London  2018 NBA Draft, Undrafted        England
# 520   Middletown (NY)  2021 NBA Draft, Undrafted  United States
# 521            London  2023 NBA Draft, Undrafted        England
# 522            London  2023 NBA Draft, Undrafted        England
#
#                         League
# 0    British Basketball League
# 1    British Basketball League
# 2    British Basketball League
# 3    British Basketball League
# 4    British Basketball League
# ..                         ...
# 518  British Basketball League
# 519  British Basketball League
# 520  British Basketball League
# 521  British Basketball League
# 522  British Basketball League
#
# [523 rows x 34 columns]

# %%
british_merged_df['Position'] = british_merged_df['Position'].replace(['PG', 'SG'], 'G')
british_merged_df['Position'] = british_merged_df['Position'].replace(['SF', 'PF'], 'F')

# %%
british_merged_df
# Out:
#      Year_x Position   #            Player Team_x  GP   MPG   PPG  FGM   FGA  \
# 0      2012        G   8       Drew Lasker    SUR  23  31.8  19.3  7.1  15.5
# 1      2013        G   7       Drew Lasker    UCP  35  27.9  15.2  5.2  12.3
# 2      2014        G  12       Drew Lasker    NEW  31  22.1  18.5  7.6  16.1
# 3      2015        G   7       Drew Lasker    NEW  37  18.7  19.8  7.5  16.4
# 4      2016        G   8       Drew Lasker    NEW  32  19.7  18.4  6.6  14.8
# ..      ...      ...  ..               ...    ...  ..   ...   ...  ...   ...
# 682    2023        C  16     Aaron Menzies    LEI  27  13.2  17.4  7.0  11.6
# 683    2023        C  17   Legend Robertin    MAN  31  13.0  17.2  6.6  12.2
# 684    2023        C  19     Hasahn French    NEW  25  25.1  13.9  6.5  13.5
# 685    2023        C  21  Jonathan Komagum    LON  24  14.0  10.5  3.6   9.0
# 686    2023        C  22      Samuel Keita    PLY  34   7.2   9.8  3.3   8.2
#
#       FG%  3PM  3PA   3P%  FTM  FTA   FT%  ORB   DRB   RPG  APG  SPG  BPG  \
# 0    .458  0.7  2.9  .244  4.4  6.5  .677  2.0   6.6   8.5  3.6  2.2  0.2
# 1    .424  1.1  3.8  .299  3.7  4.4  .833  2.3   6.0   8.3  5.8  2.3  0.3
# 2    .474  0.7  2.6  .270  2.5  3.6  .692  2.9   6.2   9.2  5.5  2.9  0.1
# 3    .458  0.6  2.6  .243  3.8  5.3  .701  4.1   8.1  12.2  6.0  4.2  0.0
# 4    .448  1.1  3.2  .333  4.0  6.1  .663  3.1   7.2  10.3  4.7  2.1  0.5
# ..    ...  ...  ...   ...  ...  ...   ...  ...   ...   ...  ...  ...  ...
# 682  .605  0.0  0.0  .000  3.4  6.5  .521  6.7  11.9  18.6  1.5  0.4  3.0
# 683  .539  0.0  0.0  .000  4.1  7.9  .515  5.6   7.9  13.5  1.2  0.4  3.5
# 684  .483  0.3  1.6  .190  0.6  2.1  .286  6.0  11.4  17.5  5.9  2.3  2.8
# 685  .397  1.3  3.0  .429  2.0  2.9  .700  5.3   8.6  13.9  1.9  1.1  1.3
# 686  .405  0.0  0.0  .000  3.1  8.1  .390  5.3   7.3  12.6  2.4  1.6  0.2
#
#      TOV    PF  Year_y Pos    HT   WT                  Team_y  \
# 0    3.7   3.3    2019   G   6-2  175        Newcastle Eagles
# 1    3.2   3.4    2019   G   6-2  175        Newcastle Eagles
# 2    2.9   4.6    2019   G   6-2  175        Newcastle Eagles
# 3    2.4   3.5    2019   G   6-2  175        Newcastle Eagles
# 4    3.2   2.5    2019   G   6-2  175        Newcastle Eagles
# ..   ...   ...     ...  ..   ...  ...                     ...
# 682  3.9   9.4    2023   C   7-3  265        Leicester Riders
# 683  2.6   8.0    2022   C   7-1  280        Surrey Scorchers
# 684  3.1   6.4    2023   F   6-7  240        Newcastle Eagles
# 685  1.7   4.6    2023   C   6-9  215            London Lions
# 686  3.5  11.8    2023   C  6-10  216  Plymouth City Patriots
#
#           Birth City               Draft Status    Nationality  \
# 0          Katy (TX)  2005 NBA Draft, Undrafted  United States
# 1          Katy (TX)  2005 NBA Draft, Undrafted  United States
# 2          Katy (TX)  2005 NBA Draft, Undrafted  United States
# 3          Katy (TX)  2005 NBA Draft, Undrafted  United States
# 4          Katy (TX)  2005 NBA Draft, Undrafted  United States
# ..               ...                        ...            ...
# 682       Manchester  2020 NBA Draft, Undrafted        England
# 683           London  2018 NBA Draft, Undrafted        England
# 684  Middletown (NY)  2021 NBA Draft, Undrafted  United States
# 685           London  2023 NBA Draft, Undrafted        England
# 686           London  2023 NBA Draft, Undrafted        England
#
#                         League
# 0    British Basketball League
# 1    British Basketball League
# 2    British Basketball League
# 3    British Basketball League
# 4    British Basketball League
# ..                         ...
# 682  British Basketball League
# 683  British Basketball League
# 684  British Basketball League
# 685  British Basketball League
# 686  British Basketball League
#
# [687 rows x 34 columns]

# %%
# british_merged_df = british_merged_df.drop_duplicates(subset=['Player'])

# %%
# Assuming british_merged_df is your DataFrame
british_merged_df.to_csv('british_merged_df.csv', index=False)
