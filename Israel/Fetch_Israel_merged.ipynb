# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
#Import dataframes 

df_stats_Israel = pd.read_csv('DataFiles/euroleague_stats_Israel.csv')
df_player_stats_Israel= pd.read_csv('DataFiles/euroleague_stats_Israel_player.csv')

# %%
df_player_stats_Israel.nunique()
# Out:
# Year              5
# Player          767
# Pos               6
# HT               19
# WT               82
# Team             18
# Birth City      360
# Draft Status     89
# Nationality      75
# dtype: int64

# %%
# columns_to_delete = ['PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2', 'TD3', 'WNBA_FANTASY_PTS', 'GP_RANK',
#                      'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK',
#                      'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK',
#                      'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK',
#                      'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK',
#                      'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK',
#                      'DD2_RANK', 'TD3_RANK', 'WNBA_FANTASY_PTS_RANK']

# # Delete the specified columns
# df_player_stats.drop(columns=columns_to_delete, inplace=True, errors='ignore')

# df_player_stats.rename(columns={'Season_type': 'Season'}, inplace=True)

# %%
df_player_stats_Israel=df_player_stats_Israel.drop_duplicates(subset=['Player'])

# %%
# Merge 'df_player_stats' and ‘df_bio‘ on common keys ‘PLAYER_ID‘ and ‘Year‘ in order to get 'COUNTRY' column.
merged_df_stats_Israel = pd.merge(df_stats_Israel, df_player_stats_Israel, on=['Player'], how='inner')

#columns_to_delete_merged = ['GP_y','PTS_y','REB_y','AST_y','NET_RATING','OREB_PCT','DREB_PCT','USG_PCT', 'TS_PCT','AST_PCT']

#merged_df_stats_bio.drop(columns=columns_to_delete_merged, inplace=True)

# %%
# Checking the result of 'merged_df_stats_bio'
merged_df_stats_Israel
# Out:
#      Year_x Position   #             Player Team_x    GP     MPG     PPG  \
# 0      2019        G   2   Scottie Wilbekin    MAC  33.0  29.875  34.375
# 1      2020        G   3   Scottie Wilbekin    MAC  27.0  31.625  30.750
# 2      2021        G   2   Scottie Wilbekin    MAC  27.0  32.250  38.000
# 3      2022        G   7   Scottie Wilbekin    MAC  30.0  35.375  28.375
# 4      2019        G   3  John DiBartolomeo    MAC  37.0  28.000  30.750
# ..      ...      ...  ..                ...    ...   ...     ...     ...
# 638    2023        C  15         Chad Brown    GAL  20.0  29.250  23.125
# 639    2023        C  16       Tidjan Keita   BEER  10.0  31.875  22.625
# 640    2023        C  17    Mangok Mathiang    EIL  11.0  37.375  22.250
# 641    2023        C  18       Marvin Jones    HAP  27.0  36.125  20.125
# 642    2023        C  19      Jonathan Levy    EIL  17.0  10.500  19.250
#
#         FGM     FGA      FG%    3PM     3PA      3P%    FTM    FTA      FT%  \
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
merged_df_stats_Israel

# %%
merged_df_stats_Israel[(merged_df_stats_Israel['Player'] == 'Scottie Wilbekin')]

# %%
merged_df_stats_Israel['League'] = 'Israeli BSL'

# %%
merged_df_stats_Israel.shape
# Out:
# (643, 34)

# %%
import numpy as np
merged_df_stats_Israel['WT'].replace('-',np.NaN,inplace=True)

# %%
merged_df_stats_Israel
# Out:
#      Year_x Position   #             Player Team_x    GP     MPG     PPG  \
# 0      2019        G   2   Scottie Wilbekin    MAC  33.0  29.875  34.375
# 1      2020        G   3   Scottie Wilbekin    MAC  27.0  31.625  30.750
# 2      2021        G   2   Scottie Wilbekin    MAC  27.0  32.250  38.000
# 3      2022        G   7   Scottie Wilbekin    MAC  30.0  35.375  28.375
# 4      2019        G   3  John DiBartolomeo    MAC  37.0  28.000  30.750
# ..      ...      ...  ..                ...    ...   ...     ...     ...
# 638    2023        C  15         Chad Brown    GAL  20.0  29.250  23.125
# 639    2023        C  16       Tidjan Keita   BEER  10.0  31.875  22.625
# 640    2023        C  17    Mangok Mathiang    EIL  11.0  37.375  22.250
# 641    2023        C  18       Marvin Jones    HAP  27.0  36.125  20.125
# 642    2023        C  19      Jonathan Levy    EIL  17.0  10.500  19.250
#
#         FGM     FGA      FG%    3PM     3PA      3P%    FTM    FTA      FT%  \
# ...

# %%
merged_df_stats_Israel.to_csv('DataFiles/euroleague_stats_Israel_merged.csv', index=False)

# %%
merged_df_stats_Israel.info()
