# %%
import pandas as pd

# %%
#Import dataframe
df_stats = pd.read_csv('/Users/pandit1781/NEAT-Scouting-Data-Analytics/Germany/bbl_stats.csv', low_memory=False)
df_bio = pd.read_csv('/Users/pandit1781/NEAT-Scouting-Data-Analytics/Germany/bbl_playerbio.csv', low_memory=False)

# %%
merged_df = pd.merge(df_stats, df_bio, on=['Player'], how='inner')

# %%
merged_df.head()
# Out:
#    Year_x Position   #             Player Team_x  GP     MPG     PPG     FGM  \
# 0    2019        G   2  Deandre Lansdowne    BLB  34  40.250  34.625  12.500
# 1    2024        G  17  Deandre Lansdowne    BVC  26  33.625  28.625  10.875
# 2    2019        G   7       Jordan Hulls    OLI  28  30.625  31.500  10.875
# 3    2020        G   9       Jordan Hulls    OLI  21  27.250  30.500  10.750
# 4    2021        G  22       Jordan Hulls    LUD  41  37.750  24.750   8.125
#
#       FGA  ...    TOV     PF  Year_y  Pos   HT   WT            Team_y  \
# 0  28.250  ...  3.875  4.875    2023    G  6-2  175    BV Chemnitz 99
# 1  22.750  ...  5.625  6.125    2023    G  6-2  175    BV Chemnitz 99
# 2  21.625  ...  4.375  4.875    2019    G  6-0  182  s.Oliver Baskets
# 3  24.375  ...  3.750  4.375    2019    G  6-0  182  s.Oliver Baskets
# 4  18.125  ...  3.125  4.000    2019    G  6-0  182  s.Oliver Baskets
#
#          Birth City               Draft Status    Nationality
# ...

# %%
merged_df[merged_df['Player'] == 'Niels Giffey']
# Out:
#      Year_x Position   #        Player Team_x  GP     MPG     PPG     FGM  \
# 106    2019        F   6  Niels Giffey    BER  40  23.875  30.250  11.375
# 107    2020        F   4  Niels Giffey    BER  29  23.875  32.000  11.375
# 108    2021        F   5  Niels Giffey    BER  34  25.375  30.125  10.875
# 109    2023        F  30  Niels Giffey    BAY  32  26.875  20.625   7.500
# 110    2024        F  42  Niels Giffey    BAY  23  24.375  18.375   7.000
#
#         FGA  ...    TOV     PF  Year_y  Pos   HT   WT       Team_y  \
# 106  21.750  ...  2.625  5.875    2019   GF  6-7  205  ALBA Berlin
# 107  21.625  ...  3.375  6.750    2019   GF  6-7  205  ALBA Berlin
# 108  21.625  ...  4.000  7.625    2019   GF  6-7  205  ALBA Berlin
# 109  15.750  ...  3.000  6.250    2019   GF  6-7  205  ALBA Berlin
# 110  14.250  ...  2.625  6.250    2019   GF  6-7  205  ALBA Berlin
#
#      Birth City               Draft Status  Nationality
# 106      Berlin  2014 NBA Draft, Undrafted      Germany
# ...

# %%
# Players to whom more than 4 rows are assigned
merged_df[merged_df.groupby('Player').transform('size')>4]
# Out:
#      Year_x Position   #                      Player Team_x  GP     MPG  \
# 29     2019        G  23                    Maodo Lo    BAY  41  24.375
# 30     2020        G  26                    Maodo Lo    BAY  25  27.125
# 31     2021        G  14                    Maodo Lo    BER  37  24.625
# 32     2022        G  15                    Maodo Lo    BER  39  26.000
# 33     2023        G  22                    Maodo Lo    BER  29  26.750
# ..      ...      ...  ..                         ...    ...  ..     ...
# 582    2020        C  30  Jonas Wohlfarth-Bottermann    LUD  31  18.750
# 583    2021        C  31  Jonas Wohlfarth-Bottermann    LUD  40  16.625
# 584    2022        C  28  Jonas Wohlfarth-Bottermann    LUD  37  17.000
# 585    2023        C  10  Jonas Wohlfarth-Bottermann    HAM  33  17.875
# 586    2024        C  25  Jonas Wohlfarth-Bottermann    HAM  26  19.875
#
#         PPG     FGM     FGA  ...    TOV      PF  Year_y  Pos    HT   WT  \
# ...

# %%
merged_df['League'] = 'German BBL'

# %%
# Export to CSV
merged_df.to_csv('german_league.csv', index=False)
